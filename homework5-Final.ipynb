# %% [markdown]
# # コンペティション課題5

# %% [markdown]
# ## 課題
# 変分オートエンコーダ（VAE）により, FashionMNISTの画像を生成してみましょう。

# %% [markdown]
# ## 目標値
# ELBO (周辺尤度下界): -240以上 (大きいほど良い)

# %% [markdown]
# ## ルール
# - 「修正しないでください」とあるセルを、修正しないでください。
# - 基本的なアーキテクチャはVAEとしてください。内部のアーキテクチャは自由です。
# - 以下のセル内の`x_train`以外の学習データは使わないでください。

# %% [markdown]
# ## 提出方法
# - 1つのファイルを提出していただきます。
#   1. テストデータ`x_test`に対する予測ラベルを`submission5_gen.csv`として保存・ダウンロードしてください。
#   2. Homeworkタブから**Day5 Pred (.csv)**を選択して提出してください。
#   3. それとは別に、最終提出に対応するノートブックを[Final Submission]などと命名しわかるようにiLect System上に置いておいてください。
# - 成績優秀者には、次回講義にて取り組みの発表をお願いいたします。
#
# ## LeaderBoard
# - コンペティション期間中のLeaderBoardは提出されたcsvファイルのうち50%を使って計算されます。
# - コンペティション終了時には提出されたcsvファイルのうち、コンペティション期間中のLeaderBoard計算に使われなかったもう半分のデータがスコア計算に使用されます。
# - このため、コンペ中の順位とコンペ終了後にLeaderBoardが更新された後の順位やスコアが食い違うことがあります。

# %% [markdown]
# ## 評価方法
# - 評価は生成画像のテストデータに対するELBOで行います.  $\sum_{i=1}^D x_i\log \hat{x}_i + (1-x_i)\log (1-\hat{x}_i) - KL\ divergence$
# - このスコアが大きいほど、良いモデルとなっています。

# %% [markdown]
# ## データの読み込み
#
# - このセルは修正しないでください。
# - 誤って修正した場合は、元ファイルをコピーし直してください。

# %%
import numpy as np
import csv
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F


def kl_divergence(mean, var):
    return -0.5*(1 + np.log(var) - mean**2 - var).sum(axis=1)


def clip_log(x):
    return torch.log(torch.clamp(x, 1e-10, None))


### データとイテレータの準備 ###

class train_dataset(torch.utils.data.Dataset):
    def __init__(self, x_train, transform=None):
        self.x_train = x_train.reshape(-1, 1, 28, 28).astype('float32') / 255
        self.transform = transform

    def __len__(self):
        return self.x_train.shape[0]

    def __getitem__(self, idx):
        data = torch.tensor(self.x_train[idx], dtype=torch.float)
        if self.transform:
            data = self.transform(data)
        return data


class test_dataset(torch.utils.data.Dataset):
    def __init__(self, x_test, transform=None):
        self.x_test = x_test.reshape(-1, 1, 28, 28).astype('float32') / 255
        self.transform = transform

    def __len__(self):
        return self.x_test.shape[0]

    def __getitem__(self, idx):
        data = torch.tensor(self.x_test[idx], dtype=torch.float)
        if self.transform:
            data = self.transform(data)
        return data


# 学習データ
x_train = np.load('/root/userspace/public/day5/homework5/data/x_train.npy')
# テストデータ
x_test = np.load('/root/userspace/public/day5/homework5/data/x_test.npy')
    
train_data = train_dataset(x_train)
test_data = test_dataset(x_test)

batch_size = 32
test_size = 50

dataloader_train = torch.utils.data.DataLoader(
    train_data,
    batch_size=batch_size,
    shuffle=True
)

dataloader_test = torch.utils.data.DataLoader(
    test_data,
    batch_size=test_size,
    shuffle=False
)

# %% [markdown]
# ## VAEの実装

# %%
rng = np.random.RandomState(1234)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


class VAE(nn.Module):
    def __init__(self, input_size=784, hidden_size=400, z_dim=10):
        super(VAE, self).__init__()
        # encoder
        self.h1 = nn.Linear(input_size, hidden_size)
        self.batchnorm1 = nn.BatchNorm1d(400)
        self.h2 = nn.Linear(hidden_size, hidden_size)
        self.mean = nn.Linear(hidden_size, z_dim)
        self.var = nn.Linear(hidden_size, z_dim)
        # decoder
        self.h3 = nn.Linear(z_dim, hidden_size)
        self.batchnorm2 = nn.BatchNorm1d(400)
        self.h4 = nn.Linear(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, input_size)
    def encode(self, x):
        h1 = F.relu(self.h1(x))
        h1 = self.batchnorm1(h1)
        h2 = F.relu(self.h2(h1))
        mean = self.mean(h2)
        var = F.softplus(self.var(h2))
        return mean, var
    
    def sampling_z(self, mean, var):
        epsilon = torch.randn(mean.shape).to(device)
        z = mean + torch.sqrt(var) * epsilon
        return z
    
    def decode(self, z): 
        h3 = F.relu(self.h3(z))
        h3 = self.batchnorm2(h3) 
        h4 = F.relu(self.h4(h3))
        
        y = torch.sigmoid(self.out(h4))
        return y
        
    def lower_bound(self, x):
        # encode
        mean, var = self.encode(x)
        KL = -0.5 * torch.mean(torch.sum(1+clip_log(var) - mean**2 - var, dim=1))
        
        # z
        z = self.sampling_z(mean, var)

        # decode
        y = self.decode(z)
        reconstruction = torch.mean(torch.sum(x*clip_log(y) + (1-x) * clip_log(1-y), dim=1))
        
        return reconstruction, KL # lower_bound


model = VAE().to(device)
optimizer = torch.optim.Adam(model.parameters(),lr=0.0003)


num_epochs=100
for epoch in range(num_epochs):
    for i, x in enumerate(dataloader_train):
        x = x.to(device).view(-1, 784)
        reconst_loss, kl_div  = model.lower_bound(x)
        loss =  - (reconst_loss - kl_div)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1)%100 == 0:
            print(f"Epoch:{epoch+1}/{num_epochs}, Step:{i+1}/{len(dataloader_train)}, Lower Bound:{-loss.item():.2f}, Reconst:{reconst_loss.item():.2f}, KL:{-kl_div.item():.2f}")
            

# Encode
for x in dataloader_test:
    x = x.to(device)
    mean, var = model.encode(x.reshape(-1, 784))
sample_z = mean

# Decode
sample_x = model.decode(sample_z)

mean = mean.cpu().detach().numpy()
var = var.cpu().detach().numpy()
sample_x = sample_x.cpu().detach().numpy()

kl = kl_divergence(mean, var)
result = np.concatenate([sample_x.reshape(-1, 28*28), kl.reshape(-1, 1)], 1).tolist()
with open('/root/userspace/submission5_gen240.csv', 'w') as file:
    writer = csv.writer(file, lineterminator='\n')
    writer.writerows(result)
# Out:
# Epoch:1/100, Step:100/2186, Lower Bound:-286.40, Reconst:-275.89, KL:-10.51
# Epoch:1/100, Step:200/2186, Lower Bound:-279.81, Reconst:-267.94, KL:-11.87
# Epoch:1/100, Step:300/2186, Lower Bound:-259.85, Reconst:-247.61, KL:-12.24
# Epoch:1/100, Step:400/2186, Lower Bound:-263.59, Reconst:-251.60, KL:-11.99
# Epoch:1/100, Step:500/2186, Lower Bound:-243.00, Reconst:-231.56, KL:-11.45
# Epoch:1/100, Step:600/2186, Lower Bound:-278.39, Reconst:-265.86, KL:-12.53
# Epoch:1/100, Step:700/2186, Lower Bound:-247.98, Reconst:-235.80, KL:-12.18
# Epoch:1/100, Step:800/2186, Lower Bound:-262.83, Reconst:-249.83, KL:-13.00
# Epoch:1/100, Step:900/2186, Lower Bound:-264.67, Reconst:-251.66, KL:-13.01
# Epoch:1/100, Step:1000/2186, Lower Bound:-243.71, Reconst:-231.10, KL:-12.62
# Epoch:1/100, Step:1100/2186, Lower Bound:-262.75, Reconst:-250.18, KL:-12.57
# Epoch:1/100, Step:1200/2186, Lower Bound:-279.50, Reconst:-265.79, KL:-13.71
# Epoch:1/100, Step:1300/2186, Lower Bound:-255.30, Reconst:-241.50, KL:-13.81
# Epoch:1/100, Step:1400/2186, Lower Bound:-251.67, Reconst:-238.44, KL:-13.23
# Epoch:1/100, Step:1500/2186, Lower Bound:-282.50, Reconst:-269.26, KL:-13.24
# Epoch:1/100, Step:1600/2186, Lower Bound:-246.55, Reconst:-233.03, KL:-13.51
# Epoch:1/100, Step:1700/2186, Lower Bound:-242.83, Reconst:-229.35, KL:-13.48
# Epoch:1/100, Step:1800/2186, Lower Bound:-256.57, Reconst:-243.40, KL:-13.17
# Epoch:1/100, Step:1900/2186, Lower Bound:-244.45, Reconst:-231.81, KL:-12.65
# Epoch:1/100, Step:2000/2186, Lower Bound:-263.37, Reconst:-249.90, KL:-13.47
# Epoch:1/100, Step:2100/2186, Lower Bound:-248.94, Reconst:-236.15, KL:-12.79
# Epoch:2/100, Step:100/2186, Lower Bound:-274.43, Reconst:-260.88, KL:-13.55
# Epoch:2/100, Step:200/2186, Lower Bound:-253.59, Reconst:-239.66, KL:-13.93
# Epoch:2/100, Step:300/2186, Lower Bound:-253.12, Reconst:-239.16, KL:-13.96
# Epoch:2/100, Step:400/2186, Lower Bound:-264.22, Reconst:-250.22, KL:-14.00
# Epoch:2/100, Step:500/2186, Lower Bound:-228.16, Reconst:-214.38, KL:-13.78
# Epoch:2/100, Step:600/2186, Lower Bound:-276.59, Reconst:-262.50, KL:-14.09
# Epoch:2/100, Step:700/2186, Lower Bound:-229.13, Reconst:-215.50, KL:-13.62
# Epoch:2/100, Step:800/2186, Lower Bound:-239.02, Reconst:-225.51, KL:-13.51
# Epoch:2/100, Step:900/2186, Lower Bound:-248.54, Reconst:-234.92, KL:-13.62
# Epoch:2/100, Step:1000/2186, Lower Bound:-276.67, Reconst:-263.08, KL:-13.60
# Epoch:2/100, Step:1100/2186, Lower Bound:-233.33, Reconst:-220.16, KL:-13.17
# Epoch:2/100, Step:1200/2186, Lower Bound:-263.17, Reconst:-249.09, KL:-14.08
# Epoch:2/100, Step:1300/2186, Lower Bound:-242.51, Reconst:-228.63, KL:-13.88
# Epoch:2/100, Step:1400/2186, Lower Bound:-249.51, Reconst:-235.73, KL:-13.78
# Epoch:2/100, Step:1500/2186, Lower Bound:-295.50, Reconst:-281.22, KL:-14.28
# Epoch:2/100, Step:1600/2186, Lower Bound:-250.39, Reconst:-236.41, KL:-13.98
# Epoch:2/100, Step:1700/2186, Lower Bound:-244.31, Reconst:-230.53, KL:-13.77
# Epoch:2/100, Step:1800/2186, Lower Bound:-230.62, Reconst:-216.50, KL:-14.12
# Epoch:2/100, Step:1900/2186, Lower Bound:-238.79, Reconst:-225.32, KL:-13.46
# Epoch:2/100, Step:2000/2186, Lower Bound:-221.74, Reconst:-208.19, KL:-13.55
# Epoch:2/100, Step:2100/2186, Lower Bound:-261.00, Reconst:-247.21, KL:-13.79
# Epoch:3/100, Step:100/2186, Lower Bound:-232.64, Reconst:-219.42, KL:-13.22
# Epoch:3/100, Step:200/2186, Lower Bound:-243.22, Reconst:-228.92, KL:-14.30
# Epoch:3/100, Step:300/2186, Lower Bound:-244.16, Reconst:-229.98, KL:-14.18
# Epoch:3/100, Step:400/2186, Lower Bound:-240.95, Reconst:-226.87, KL:-14.08
# Epoch:3/100, Step:500/2186, Lower Bound:-226.54, Reconst:-212.55, KL:-13.99
# Epoch:3/100, Step:600/2186, Lower Bound:-229.93, Reconst:-215.97, KL:-13.97
# Epoch:3/100, Step:700/2186, Lower Bound:-254.14, Reconst:-239.99, KL:-14.15
# Epoch:3/100, Step:800/2186, Lower Bound:-247.44, Reconst:-233.60, KL:-13.84
# Epoch:3/100, Step:900/2186, Lower Bound:-245.22, Reconst:-231.06, KL:-14.16
# Epoch:3/100, Step:1000/2186, Lower Bound:-242.18, Reconst:-228.10, KL:-14.07
# Epoch:3/100, Step:1100/2186, Lower Bound:-218.99, Reconst:-205.35, KL:-13.64
# Epoch:3/100, Step:1200/2186, Lower Bound:-254.41, Reconst:-240.60, KL:-13.82
# Epoch:3/100, Step:1300/2186, Lower Bound:-250.59, Reconst:-236.56, KL:-14.03
# Epoch:3/100, Step:1400/2186, Lower Bound:-245.95, Reconst:-232.16, KL:-13.79
# Epoch:3/100, Step:1500/2186, Lower Bound:-253.46, Reconst:-239.33, KL:-14.14
# Epoch:3/100, Step:1600/2186, Lower Bound:-251.00, Reconst:-236.66, KL:-14.34
# Epoch:3/100, Step:1700/2186, Lower Bound:-281.95, Reconst:-267.08, KL:-14.87
# Epoch:3/100, Step:1800/2186, Lower Bound:-259.08, Reconst:-244.77, KL:-14.31
# Epoch:3/100, Step:1900/2186, Lower Bound:-232.77, Reconst:-218.86, KL:-13.92
# Epoch:3/100, Step:2000/2186, Lower Bound:-252.77, Reconst:-238.82, KL:-13.95
# Epoch:3/100, Step:2100/2186, Lower Bound:-246.98, Reconst:-232.60, KL:-14.38
# Epoch:4/100, Step:100/2186, Lower Bound:-251.03, Reconst:-236.88, KL:-14.15
# Epoch:4/100, Step:200/2186, Lower Bound:-232.60, Reconst:-218.33, KL:-14.27
# Epoch:4/100, Step:300/2186, Lower Bound:-242.60, Reconst:-228.16, KL:-14.44
# Epoch:4/100, Step:400/2186, Lower Bound:-238.65, Reconst:-224.09, KL:-14.56
# Epoch:4/100, Step:500/2186, Lower Bound:-247.33, Reconst:-232.74, KL:-14.58
# Epoch:4/100, Step:600/2186, Lower Bound:-233.91, Reconst:-219.75, KL:-14.17
# Epoch:4/100, Step:700/2186, Lower Bound:-230.90, Reconst:-216.84, KL:-14.06
# Epoch:4/100, Step:800/2186, Lower Bound:-237.46, Reconst:-222.71, KL:-14.75
# Epoch:4/100, Step:900/2186, Lower Bound:-250.02, Reconst:-236.02, KL:-14.01
# Epoch:4/100, Step:1000/2186, Lower Bound:-244.15, Reconst:-230.03, KL:-14.13
# Epoch:4/100, Step:1100/2186, Lower Bound:-225.75, Reconst:-212.07, KL:-13.68
# Epoch:4/100, Step:1200/2186, Lower Bound:-260.71, Reconst:-247.00, KL:-13.71
# Epoch:4/100, Step:1300/2186, Lower Bound:-249.24, Reconst:-235.48, KL:-13.76
# Epoch:4/100, Step:1400/2186, Lower Bound:-240.39, Reconst:-226.05, KL:-14.35
# Epoch:4/100, Step:1500/2186, Lower Bound:-245.18, Reconst:-231.56, KL:-13.61
# Epoch:4/100, Step:1600/2186, Lower Bound:-260.88, Reconst:-246.48, KL:-14.40
# Epoch:4/100, Step:1700/2186, Lower Bound:-254.57, Reconst:-240.17, KL:-14.40
# Epoch:4/100, Step:1800/2186, Lower Bound:-225.80, Reconst:-211.47, KL:-14.33
# Epoch:4/100, Step:1900/2186, Lower Bound:-246.10, Reconst:-231.48, KL:-14.62
# Epoch:4/100, Step:2000/2186, Lower Bound:-270.37, Reconst:-255.65, KL:-14.72
# Epoch:4/100, Step:2100/2186, Lower Bound:-269.47, Reconst:-254.73, KL:-14.74
# Epoch:5/100, Step:100/2186, Lower Bound:-256.54, Reconst:-241.58, KL:-14.96
# Epoch:5/100, Step:200/2186, Lower Bound:-248.51, Reconst:-234.12, KL:-14.39
# Epoch:5/100, Step:300/2186, Lower Bound:-234.40, Reconst:-220.22, KL:-14.19
# Epoch:5/100, Step:400/2186, Lower Bound:-230.18, Reconst:-216.40, KL:-13.78
# Epoch:5/100, Step:500/2186, Lower Bound:-226.91, Reconst:-212.71, KL:-14.20
# Epoch:5/100, Step:600/2186, Lower Bound:-226.56, Reconst:-212.42, KL:-14.14
# Epoch:5/100, Step:700/2186, Lower Bound:-244.15, Reconst:-229.88, KL:-14.27
# Epoch:5/100, Step:800/2186, Lower Bound:-250.89, Reconst:-236.07, KL:-14.82
# Epoch:5/100, Step:900/2186, Lower Bound:-249.56, Reconst:-235.35, KL:-14.21
# Epoch:5/100, Step:1000/2186, Lower Bound:-242.21, Reconst:-227.90, KL:-14.31
# Epoch:5/100, Step:1100/2186, Lower Bound:-233.08, Reconst:-218.51, KL:-14.57
# Epoch:5/100, Step:1200/2186, Lower Bound:-229.02, Reconst:-214.85, KL:-14.16
# Epoch:5/100, Step:1300/2186, Lower Bound:-227.27, Reconst:-212.86, KL:-14.41
# Epoch:5/100, Step:1400/2186, Lower Bound:-240.70, Reconst:-226.39, KL:-14.31
# Epoch:5/100, Step:1500/2186, Lower Bound:-246.82, Reconst:-232.19, KL:-14.64
# Epoch:5/100, Step:1600/2186, Lower Bound:-253.85, Reconst:-238.89, KL:-14.96
# Epoch:5/100, Step:1700/2186, Lower Bound:-256.25, Reconst:-241.43, KL:-14.81
# Epoch:5/100, Step:1800/2186, Lower Bound:-235.40, Reconst:-220.95, KL:-14.45
# Epoch:5/100, Step:1900/2186, Lower Bound:-249.61, Reconst:-235.29, KL:-14.32
# Epoch:5/100, Step:2000/2186, Lower Bound:-228.63, Reconst:-214.78, KL:-13.85
# Epoch:5/100, Step:2100/2186, Lower Bound:-259.44, Reconst:-244.22, KL:-15.23
# Epoch:6/100, Step:100/2186, Lower Bound:-245.00, Reconst:-230.54, KL:-14.46
# Epoch:6/100, Step:200/2186, Lower Bound:-257.19, Reconst:-242.78, KL:-14.41
# Epoch:6/100, Step:300/2186, Lower Bound:-232.04, Reconst:-217.40, KL:-14.64
# Epoch:6/100, Step:400/2186, Lower Bound:-229.71, Reconst:-215.95, KL:-13.77
# Epoch:6/100, Step:500/2186, Lower Bound:-254.64, Reconst:-240.45, KL:-14.19
# Epoch:6/100, Step:600/2186, Lower Bound:-235.93, Reconst:-221.56, KL:-14.38
# Epoch:6/100, Step:700/2186, Lower Bound:-254.97, Reconst:-240.28, KL:-14.69
# Epoch:6/100, Step:800/2186, Lower Bound:-268.59, Reconst:-254.08, KL:-14.50
# Epoch:6/100, Step:900/2186, Lower Bound:-231.02, Reconst:-216.76, KL:-14.26
# Epoch:6/100, Step:1000/2186, Lower Bound:-225.07, Reconst:-210.70, KL:-14.37
# Epoch:6/100, Step:1100/2186, Lower Bound:-246.58, Reconst:-231.94, KL:-14.64
# Epoch:6/100, Step:1200/2186, Lower Bound:-248.87, Reconst:-234.12, KL:-14.75
# Epoch:6/100, Step:1300/2186, Lower Bound:-239.70, Reconst:-224.57, KL:-15.13
# Epoch:6/100, Step:1400/2186, Lower Bound:-223.61, Reconst:-209.90, KL:-13.70
# Epoch:6/100, Step:1500/2186, Lower Bound:-251.51, Reconst:-236.56, KL:-14.96
# Epoch:6/100, Step:1600/2186, Lower Bound:-257.63, Reconst:-243.40, KL:-14.23
# Epoch:6/100, Step:1700/2186, Lower Bound:-245.46, Reconst:-230.77, KL:-14.69
# Epoch:6/100, Step:1800/2186, Lower Bound:-246.22, Reconst:-231.18, KL:-15.04
# Epoch:6/100, Step:1900/2186, Lower Bound:-240.30, Reconst:-225.38, KL:-14.92
# Epoch:6/100, Step:2000/2186, Lower Bound:-238.64, Reconst:-224.63, KL:-14.01
# Epoch:6/100, Step:2100/2186, Lower Bound:-252.73, Reconst:-238.43, KL:-14.30
# Epoch:7/100, Step:100/2186, Lower Bound:-242.54, Reconst:-227.32, KL:-15.22
# Epoch:7/100, Step:200/2186, Lower Bound:-228.10, Reconst:-213.78, KL:-14.32
# Epoch:7/100, Step:300/2186, Lower Bound:-238.06, Reconst:-223.12, KL:-14.95
# Epoch:7/100, Step:400/2186, Lower Bound:-240.44, Reconst:-225.88, KL:-14.56
# Epoch:7/100, Step:500/2186, Lower Bound:-240.62, Reconst:-226.37, KL:-14.26
# Epoch:7/100, Step:600/2186, Lower Bound:-234.22, Reconst:-220.19, KL:-14.03
# Epoch:7/100, Step:700/2186, Lower Bound:-264.65, Reconst:-249.52, KL:-15.14
# Epoch:7/100, Step:800/2186, Lower Bound:-256.09, Reconst:-240.98, KL:-15.11
# Epoch:7/100, Step:900/2186, Lower Bound:-234.07, Reconst:-219.87, KL:-14.20
# Epoch:7/100, Step:1000/2186, Lower Bound:-239.24, Reconst:-224.56, KL:-14.68
# Epoch:7/100, Step:1100/2186, Lower Bound:-243.90, Reconst:-229.53, KL:-14.36
# Epoch:7/100, Step:1200/2186, Lower Bound:-247.92, Reconst:-233.51, KL:-14.42
# Epoch:7/100, Step:1300/2186, Lower Bound:-222.51, Reconst:-208.33, KL:-14.18
# Epoch:7/100, Step:1400/2186, Lower Bound:-225.92, Reconst:-211.38, KL:-14.54
# Epoch:7/100, Step:1500/2186, Lower Bound:-253.62, Reconst:-237.40, KL:-16.22
# Epoch:7/100, Step:1600/2186, Lower Bound:-243.70, Reconst:-229.56, KL:-14.14
# Epoch:7/100, Step:1700/2186, Lower Bound:-242.82, Reconst:-228.74, KL:-14.08
# Epoch:7/100, Step:1800/2186, Lower Bound:-258.34, Reconst:-243.76, KL:-14.58
# Epoch:7/100, Step:1900/2186, Lower Bound:-241.33, Reconst:-227.25, KL:-14.09
# Epoch:7/100, Step:2000/2186, Lower Bound:-222.26, Reconst:-207.61, KL:-14.65
# Epoch:7/100, Step:2100/2186, Lower Bound:-257.78, Reconst:-243.28, KL:-14.51
# Epoch:8/100, Step:100/2186, Lower Bound:-230.40, Reconst:-215.38, KL:-15.02
# Epoch:8/100, Step:200/2186, Lower Bound:-241.41, Reconst:-227.55, KL:-13.86
# Epoch:8/100, Step:300/2186, Lower Bound:-232.11, Reconst:-218.03, KL:-14.07
# Epoch:8/100, Step:400/2186, Lower Bound:-232.39, Reconst:-218.89, KL:-13.50
# Epoch:8/100, Step:500/2186, Lower Bound:-247.74, Reconst:-232.82, KL:-14.93
# Epoch:8/100, Step:600/2186, Lower Bound:-241.30, Reconst:-227.17, KL:-14.13
# Epoch:8/100, Step:700/2186, Lower Bound:-238.29, Reconst:-224.00, KL:-14.28
# Epoch:8/100, Step:800/2186, Lower Bound:-239.29, Reconst:-224.83, KL:-14.46
# Epoch:8/100, Step:900/2186, Lower Bound:-222.04, Reconst:-207.90, KL:-14.14
# Epoch:8/100, Step:1000/2186, Lower Bound:-258.79, Reconst:-244.16, KL:-14.63
# Epoch:8/100, Step:1100/2186, Lower Bound:-232.87, Reconst:-218.88, KL:-13.99
# Epoch:8/100, Step:1200/2186, Lower Bound:-247.38, Reconst:-232.72, KL:-14.66
# Epoch:8/100, Step:1300/2186, Lower Bound:-234.65, Reconst:-220.52, KL:-14.13
# Epoch:8/100, Step:1400/2186, Lower Bound:-249.58, Reconst:-234.75, KL:-14.83
# Epoch:8/100, Step:1500/2186, Lower Bound:-277.78, Reconst:-262.84, KL:-14.94
# Epoch:8/100, Step:1600/2186, Lower Bound:-237.60, Reconst:-223.24, KL:-14.36
# Epoch:8/100, Step:1700/2186, Lower Bound:-244.20, Reconst:-229.21, KL:-14.99
# Epoch:8/100, Step:1800/2186, Lower Bound:-254.38, Reconst:-239.64, KL:-14.74
# Epoch:8/100, Step:1900/2186, Lower Bound:-260.30, Reconst:-245.30, KL:-15.00
# Epoch:8/100, Step:2000/2186, Lower Bound:-264.16, Reconst:-249.17, KL:-14.99
# Epoch:8/100, Step:2100/2186, Lower Bound:-221.36, Reconst:-206.63, KL:-14.73
# Epoch:9/100, Step:100/2186, Lower Bound:-242.48, Reconst:-228.50, KL:-13.97
# Epoch:9/100, Step:200/2186, Lower Bound:-242.92, Reconst:-228.78, KL:-14.13
# Epoch:9/100, Step:300/2186, Lower Bound:-243.95, Reconst:-229.33, KL:-14.62
# Epoch:9/100, Step:400/2186, Lower Bound:-243.42, Reconst:-229.14, KL:-14.29
# Epoch:9/100, Step:500/2186, Lower Bound:-230.09, Reconst:-214.76, KL:-15.33
# Epoch:9/100, Step:600/2186, Lower Bound:-250.29, Reconst:-235.77, KL:-14.52
# Epoch:9/100, Step:700/2186, Lower Bound:-224.18, Reconst:-209.88, KL:-14.31
# Epoch:9/100, Step:800/2186, Lower Bound:-249.97, Reconst:-235.44, KL:-14.53
# Epoch:9/100, Step:900/2186, Lower Bound:-262.75, Reconst:-248.17, KL:-14.58
# Epoch:9/100, Step:1000/2186, Lower Bound:-250.95, Reconst:-236.33, KL:-14.62
# Epoch:9/100, Step:1100/2186, Lower Bound:-243.39, Reconst:-228.98, KL:-14.42
# Epoch:9/100, Step:1200/2186, Lower Bound:-237.23, Reconst:-222.83, KL:-14.40
# Epoch:9/100, Step:1300/2186, Lower Bound:-230.56, Reconst:-216.04, KL:-14.52
# Epoch:9/100, Step:1400/2186, Lower Bound:-233.58, Reconst:-218.57, KL:-15.01
# Epoch:9/100, Step:1500/2186, Lower Bound:-235.75, Reconst:-221.08, KL:-14.67
# Epoch:9/100, Step:1600/2186, Lower Bound:-227.56, Reconst:-213.60, KL:-13.96
# Epoch:9/100, Step:1700/2186, Lower Bound:-243.64, Reconst:-228.61, KL:-15.04
# Epoch:9/100, Step:1800/2186, Lower Bound:-249.50, Reconst:-235.29, KL:-14.20
# Epoch:9/100, Step:1900/2186, Lower Bound:-253.93, Reconst:-239.04, KL:-14.88
# Epoch:9/100, Step:2000/2186, Lower Bound:-257.22, Reconst:-242.58, KL:-14.65
# Epoch:9/100, Step:2100/2186, Lower Bound:-223.88, Reconst:-209.94, KL:-13.94
# Epoch:10/100, Step:100/2186, Lower Bound:-238.09, Reconst:-223.36, KL:-14.73
# Epoch:10/100, Step:200/2186, Lower Bound:-229.38, Reconst:-214.92, KL:-14.46
# Epoch:10/100, Step:300/2186, Lower Bound:-258.32, Reconst:-244.17, KL:-14.15
# Epoch:10/100, Step:400/2186, Lower Bound:-253.11, Reconst:-238.31, KL:-14.80
# Epoch:10/100, Step:500/2186, Lower Bound:-226.78, Reconst:-212.37, KL:-14.41
# Epoch:10/100, Step:600/2186, Lower Bound:-234.88, Reconst:-220.55, KL:-14.33
# Epoch:10/100, Step:700/2186, Lower Bound:-251.95, Reconst:-238.04, KL:-13.90
# Epoch:10/100, Step:800/2186, Lower Bound:-259.30, Reconst:-244.62, KL:-14.68
# Epoch:10/100, Step:900/2186, Lower Bound:-254.77, Reconst:-239.91, KL:-14.86
# Epoch:10/100, Step:1000/2186, Lower Bound:-240.04, Reconst:-225.57, KL:-14.47
# Epoch:10/100, Step:1100/2186, Lower Bound:-244.46, Reconst:-230.18, KL:-14.28
# Epoch:10/100, Step:1200/2186, Lower Bound:-230.20, Reconst:-215.72, KL:-14.47
# Epoch:10/100, Step:1300/2186, Lower Bound:-239.29, Reconst:-225.17, KL:-14.12
# Epoch:10/100, Step:1400/2186, Lower Bound:-261.67, Reconst:-246.44, KL:-15.23
# Epoch:10/100, Step:1500/2186, Lower Bound:-247.27, Reconst:-232.58, KL:-14.70
# Epoch:10/100, Step:1600/2186, Lower Bound:-231.70, Reconst:-217.36, KL:-14.33
# Epoch:10/100, Step:1700/2186, Lower Bound:-256.45, Reconst:-241.49, KL:-14.96
# Epoch:10/100, Step:1800/2186, Lower Bound:-237.28, Reconst:-222.85, KL:-14.43
# Epoch:10/100, Step:1900/2186, Lower Bound:-261.42, Reconst:-246.50, KL:-14.92
# Epoch:10/100, Step:2000/2186, Lower Bound:-246.93, Reconst:-232.91, KL:-14.02
# Epoch:10/100, Step:2100/2186, Lower Bound:-227.44, Reconst:-213.08, KL:-14.36
# Epoch:11/100, Step:100/2186, Lower Bound:-244.25, Reconst:-229.24, KL:-15.01
# Epoch:11/100, Step:200/2186, Lower Bound:-233.12, Reconst:-218.76, KL:-14.37
# Epoch:11/100, Step:300/2186, Lower Bound:-241.65, Reconst:-227.52, KL:-14.13
# Epoch:11/100, Step:400/2186, Lower Bound:-257.21, Reconst:-242.32, KL:-14.89
# Epoch:11/100, Step:500/2186, Lower Bound:-249.25, Reconst:-234.53, KL:-14.72
# Epoch:11/100, Step:600/2186, Lower Bound:-262.99, Reconst:-248.03, KL:-14.96
# Epoch:11/100, Step:700/2186, Lower Bound:-243.32, Reconst:-228.84, KL:-14.48
# Epoch:11/100, Step:800/2186, Lower Bound:-235.48, Reconst:-220.78, KL:-14.70
# Epoch:11/100, Step:900/2186, Lower Bound:-255.91, Reconst:-241.04, KL:-14.87
# Epoch:11/100, Step:1000/2186, Lower Bound:-228.44, Reconst:-213.70, KL:-14.74
# Epoch:11/100, Step:1100/2186, Lower Bound:-260.65, Reconst:-245.19, KL:-15.46
# Epoch:11/100, Step:1200/2186, Lower Bound:-269.93, Reconst:-255.03, KL:-14.90
# Epoch:11/100, Step:1300/2186, Lower Bound:-253.84, Reconst:-239.08, KL:-14.76
# Epoch:11/100, Step:1400/2186, Lower Bound:-232.17, Reconst:-218.25, KL:-13.93
# Epoch:11/100, Step:1500/2186, Lower Bound:-221.54, Reconst:-207.12, KL:-14.42
# Epoch:11/100, Step:1600/2186, Lower Bound:-220.24, Reconst:-206.05, KL:-14.19
# Epoch:11/100, Step:1700/2186, Lower Bound:-258.93, Reconst:-243.30, KL:-15.63
# Epoch:11/100, Step:1800/2186, Lower Bound:-259.04, Reconst:-244.50, KL:-14.54
# Epoch:11/100, Step:1900/2186, Lower Bound:-220.83, Reconst:-206.79, KL:-14.04
# Epoch:11/100, Step:2000/2186, Lower Bound:-242.61, Reconst:-228.20, KL:-14.42
# Epoch:11/100, Step:2100/2186, Lower Bound:-230.14, Reconst:-215.61, KL:-14.53
# Epoch:12/100, Step:100/2186, Lower Bound:-223.40, Reconst:-208.83, KL:-14.57
# Epoch:12/100, Step:200/2186, Lower Bound:-233.91, Reconst:-219.14, KL:-14.77
# Epoch:12/100, Step:300/2186, Lower Bound:-242.40, Reconst:-228.08, KL:-14.32
# Epoch:12/100, Step:400/2186, Lower Bound:-256.72, Reconst:-242.05, KL:-14.67
# Epoch:12/100, Step:500/2186, Lower Bound:-241.18, Reconst:-226.58, KL:-14.60
# Epoch:12/100, Step:600/2186, Lower Bound:-251.49, Reconst:-236.86, KL:-14.63
# Epoch:12/100, Step:700/2186, Lower Bound:-234.96, Reconst:-219.84, KL:-15.12
# Epoch:12/100, Step:800/2186, Lower Bound:-236.61, Reconst:-222.56, KL:-14.05
# Epoch:12/100, Step:900/2186, Lower Bound:-246.45, Reconst:-231.55, KL:-14.89
# Epoch:12/100, Step:1000/2186, Lower Bound:-241.62, Reconst:-227.45, KL:-14.17
# Epoch:12/100, Step:1100/2186, Lower Bound:-240.25, Reconst:-225.74, KL:-14.51
# Epoch:12/100, Step:1200/2186, Lower Bound:-230.62, Reconst:-216.52, KL:-14.11
# Epoch:12/100, Step:1300/2186, Lower Bound:-242.77, Reconst:-227.50, KL:-15.27
# Epoch:12/100, Step:1400/2186, Lower Bound:-216.54, Reconst:-202.16, KL:-14.38
# Epoch:12/100, Step:1500/2186, Lower Bound:-255.68, Reconst:-240.46, KL:-15.22
# Epoch:12/100, Step:1600/2186, Lower Bound:-265.44, Reconst:-250.05, KL:-15.39
# Epoch:12/100, Step:1700/2186, Lower Bound:-256.04, Reconst:-241.27, KL:-14.77
# Epoch:12/100, Step:1800/2186, Lower Bound:-223.96, Reconst:-209.29, KL:-14.67
# Epoch:12/100, Step:1900/2186, Lower Bound:-246.40, Reconst:-231.59, KL:-14.81
# Epoch:12/100, Step:2000/2186, Lower Bound:-256.93, Reconst:-242.15, KL:-14.78
# Epoch:12/100, Step:2100/2186, Lower Bound:-237.41, Reconst:-222.64, KL:-14.77
# Epoch:13/100, Step:100/2186, Lower Bound:-256.46, Reconst:-241.14, KL:-15.32
# Epoch:13/100, Step:200/2186, Lower Bound:-249.28, Reconst:-234.34, KL:-14.95
# Epoch:13/100, Step:300/2186, Lower Bound:-224.31, Reconst:-209.77, KL:-14.54
# Epoch:13/100, Step:400/2186, Lower Bound:-229.19, Reconst:-214.77, KL:-14.41
# Epoch:13/100, Step:500/2186, Lower Bound:-249.44, Reconst:-234.82, KL:-14.62
# Epoch:13/100, Step:600/2186, Lower Bound:-278.39, Reconst:-263.15, KL:-15.24
# Epoch:13/100, Step:700/2186, Lower Bound:-243.41, Reconst:-228.89, KL:-14.52
# Epoch:13/100, Step:800/2186, Lower Bound:-238.33, Reconst:-223.91, KL:-14.42
# Epoch:13/100, Step:900/2186, Lower Bound:-248.76, Reconst:-234.06, KL:-14.70
# Epoch:13/100, Step:1000/2186, Lower Bound:-238.23, Reconst:-223.59, KL:-14.63
# Epoch:13/100, Step:1100/2186, Lower Bound:-255.20, Reconst:-239.97, KL:-15.23
# Epoch:13/100, Step:1200/2186, Lower Bound:-221.55, Reconst:-207.32, KL:-14.23
# Epoch:13/100, Step:1300/2186, Lower Bound:-244.06, Reconst:-229.46, KL:-14.60
# Epoch:13/100, Step:1400/2186, Lower Bound:-249.04, Reconst:-234.23, KL:-14.81
# Epoch:13/100, Step:1500/2186, Lower Bound:-245.21, Reconst:-230.99, KL:-14.22
# Epoch:13/100, Step:1600/2186, Lower Bound:-219.48, Reconst:-204.75, KL:-14.73
# Epoch:13/100, Step:1700/2186, Lower Bound:-232.32, Reconst:-217.08, KL:-15.24
# Epoch:13/100, Step:1800/2186, Lower Bound:-227.99, Reconst:-213.73, KL:-14.26
# Epoch:13/100, Step:1900/2186, Lower Bound:-238.59, Reconst:-224.21, KL:-14.37
# Epoch:13/100, Step:2000/2186, Lower Bound:-239.87, Reconst:-224.81, KL:-15.06
# Epoch:13/100, Step:2100/2186, Lower Bound:-244.32, Reconst:-230.45, KL:-13.87
# Epoch:14/100, Step:100/2186, Lower Bound:-261.53, Reconst:-246.88, KL:-14.65
# Epoch:14/100, Step:200/2186, Lower Bound:-241.14, Reconst:-226.28, KL:-14.85
# Epoch:14/100, Step:300/2186, Lower Bound:-236.00, Reconst:-221.09, KL:-14.91
# Epoch:14/100, Step:400/2186, Lower Bound:-236.52, Reconst:-222.33, KL:-14.19
# Epoch:14/100, Step:500/2186, Lower Bound:-266.73, Reconst:-251.71, KL:-15.01
# Epoch:14/100, Step:600/2186, Lower Bound:-251.66, Reconst:-237.02, KL:-14.64
# Epoch:14/100, Step:700/2186, Lower Bound:-254.23, Reconst:-239.11, KL:-15.12
# Epoch:14/100, Step:800/2186, Lower Bound:-238.08, Reconst:-223.51, KL:-14.57
# Epoch:14/100, Step:900/2186, Lower Bound:-259.56, Reconst:-244.53, KL:-15.03
# Epoch:14/100, Step:1000/2186, Lower Bound:-231.28, Reconst:-216.69, KL:-14.58
# Epoch:14/100, Step:1100/2186, Lower Bound:-251.53, Reconst:-236.71, KL:-14.82
# Epoch:14/100, Step:1200/2186, Lower Bound:-236.06, Reconst:-221.83, KL:-14.23
# Epoch:14/100, Step:1300/2186, Lower Bound:-250.62, Reconst:-235.92, KL:-14.70
# Epoch:14/100, Step:1400/2186, Lower Bound:-232.96, Reconst:-218.13, KL:-14.82
# Epoch:14/100, Step:1500/2186, Lower Bound:-238.89, Reconst:-223.89, KL:-15.00
# Epoch:14/100, Step:1600/2186, Lower Bound:-230.87, Reconst:-216.64, KL:-14.23
# Epoch:14/100, Step:1700/2186, Lower Bound:-251.69, Reconst:-236.62, KL:-15.07
# Epoch:14/100, Step:1800/2186, Lower Bound:-237.94, Reconst:-222.99, KL:-14.95
# Epoch:14/100, Step:1900/2186, Lower Bound:-244.90, Reconst:-230.26, KL:-14.64
# Epoch:14/100, Step:2000/2186, Lower Bound:-226.11, Reconst:-211.59, KL:-14.52
# Epoch:14/100, Step:2100/2186, Lower Bound:-228.33, Reconst:-214.41, KL:-13.92
# Epoch:15/100, Step:100/2186, Lower Bound:-251.04, Reconst:-235.81, KL:-15.23
# Epoch:15/100, Step:200/2186, Lower Bound:-212.79, Reconst:-198.58, KL:-14.21
# Epoch:15/100, Step:300/2186, Lower Bound:-235.42, Reconst:-221.15, KL:-14.27
# Epoch:15/100, Step:400/2186, Lower Bound:-259.75, Reconst:-244.65, KL:-15.10
# Epoch:15/100, Step:500/2186, Lower Bound:-215.29, Reconst:-201.01, KL:-14.29
# Epoch:15/100, Step:600/2186, Lower Bound:-238.85, Reconst:-224.39, KL:-14.46
# Epoch:15/100, Step:700/2186, Lower Bound:-227.75, Reconst:-213.12, KL:-14.63
# Epoch:15/100, Step:800/2186, Lower Bound:-219.23, Reconst:-204.73, KL:-14.50
# Epoch:15/100, Step:900/2186, Lower Bound:-223.57, Reconst:-209.14, KL:-14.43
# Epoch:15/100, Step:1000/2186, Lower Bound:-240.34, Reconst:-224.87, KL:-15.48
# Epoch:15/100, Step:1100/2186, Lower Bound:-203.76, Reconst:-189.23, KL:-14.53
# Epoch:15/100, Step:1200/2186, Lower Bound:-217.71, Reconst:-203.64, KL:-14.07
# Epoch:15/100, Step:1300/2186, Lower Bound:-254.01, Reconst:-238.81, KL:-15.20
# Epoch:15/100, Step:1400/2186, Lower Bound:-244.15, Reconst:-229.56, KL:-14.59
# Epoch:15/100, Step:1500/2186, Lower Bound:-232.01, Reconst:-217.89, KL:-14.13
# Epoch:15/100, Step:1600/2186, Lower Bound:-243.28, Reconst:-228.80, KL:-14.48
# Epoch:15/100, Step:1700/2186, Lower Bound:-236.79, Reconst:-222.32, KL:-14.46
# Epoch:15/100, Step:1800/2186, Lower Bound:-247.35, Reconst:-232.59, KL:-14.76
# Epoch:15/100, Step:1900/2186, Lower Bound:-233.37, Reconst:-219.04, KL:-14.33
# Epoch:15/100, Step:2000/2186, Lower Bound:-250.72, Reconst:-236.55, KL:-14.17
# Epoch:15/100, Step:2100/2186, Lower Bound:-240.41, Reconst:-225.59, KL:-14.82
# Epoch:16/100, Step:100/2186, Lower Bound:-229.90, Reconst:-214.64, KL:-15.26
# Epoch:16/100, Step:200/2186, Lower Bound:-227.77, Reconst:-213.40, KL:-14.38
# Epoch:16/100, Step:300/2186, Lower Bound:-245.43, Reconst:-230.52, KL:-14.91
# Epoch:16/100, Step:400/2186, Lower Bound:-253.02, Reconst:-238.07, KL:-14.96
# Epoch:16/100, Step:500/2186, Lower Bound:-240.50, Reconst:-225.78, KL:-14.72
# Epoch:16/100, Step:600/2186, Lower Bound:-239.66, Reconst:-224.67, KL:-14.99
# Epoch:16/100, Step:700/2186, Lower Bound:-252.21, Reconst:-237.46, KL:-14.75
# Epoch:16/100, Step:800/2186, Lower Bound:-227.26, Reconst:-212.28, KL:-14.98
# Epoch:16/100, Step:900/2186, Lower Bound:-271.51, Reconst:-256.46, KL:-15.06
# Epoch:16/100, Step:1000/2186, Lower Bound:-253.13, Reconst:-238.19, KL:-14.93
# Epoch:16/100, Step:1100/2186, Lower Bound:-242.68, Reconst:-228.12, KL:-14.55
# Epoch:16/100, Step:1200/2186, Lower Bound:-254.78, Reconst:-239.67, KL:-15.11
# Epoch:16/100, Step:1300/2186, Lower Bound:-239.59, Reconst:-224.82, KL:-14.76
# Epoch:16/100, Step:1400/2186, Lower Bound:-218.51, Reconst:-204.38, KL:-14.14
# Epoch:16/100, Step:1500/2186, Lower Bound:-223.72, Reconst:-208.67, KL:-15.05
# Epoch:16/100, Step:1600/2186, Lower Bound:-219.61, Reconst:-204.95, KL:-14.66
# Epoch:16/100, Step:1700/2186, Lower Bound:-265.12, Reconst:-249.96, KL:-15.16
# Epoch:16/100, Step:1800/2186, Lower Bound:-227.21, Reconst:-213.09, KL:-14.12
# Epoch:16/100, Step:1900/2186, Lower Bound:-243.19, Reconst:-228.50, KL:-14.69
# Epoch:16/100, Step:2000/2186, Lower Bound:-263.31, Reconst:-247.71, KL:-15.60
# Epoch:16/100, Step:2100/2186, Lower Bound:-240.24, Reconst:-225.27, KL:-14.97
# Epoch:17/100, Step:100/2186, Lower Bound:-237.08, Reconst:-221.49, KL:-15.58
# Epoch:17/100, Step:200/2186, Lower Bound:-266.61, Reconst:-251.40, KL:-15.22
# Epoch:17/100, Step:300/2186, Lower Bound:-241.23, Reconst:-227.15, KL:-14.09
# Epoch:17/100, Step:400/2186, Lower Bound:-235.36, Reconst:-219.82, KL:-15.54
# Epoch:17/100, Step:500/2186, Lower Bound:-247.06, Reconst:-232.09, KL:-14.97
# Epoch:17/100, Step:600/2186, Lower Bound:-228.33, Reconst:-213.98, KL:-14.36
# Epoch:17/100, Step:700/2186, Lower Bound:-233.18, Reconst:-218.36, KL:-14.82
# Epoch:17/100, Step:800/2186, Lower Bound:-219.90, Reconst:-206.08, KL:-13.82
# Epoch:17/100, Step:900/2186, Lower Bound:-229.23, Reconst:-214.68, KL:-14.56
# Epoch:17/100, Step:1000/2186, Lower Bound:-232.68, Reconst:-217.98, KL:-14.71
# Epoch:17/100, Step:1100/2186, Lower Bound:-240.13, Reconst:-225.69, KL:-14.44
# Epoch:17/100, Step:1200/2186, Lower Bound:-248.42, Reconst:-233.58, KL:-14.85
# Epoch:17/100, Step:1300/2186, Lower Bound:-241.57, Reconst:-226.86, KL:-14.71
# Epoch:17/100, Step:1400/2186, Lower Bound:-221.23, Reconst:-206.55, KL:-14.68
# Epoch:17/100, Step:1500/2186, Lower Bound:-230.81, Reconst:-216.29, KL:-14.53
# Epoch:17/100, Step:1600/2186, Lower Bound:-247.83, Reconst:-232.72, KL:-15.10
# Epoch:17/100, Step:1700/2186, Lower Bound:-231.05, Reconst:-217.00, KL:-14.05
# Epoch:17/100, Step:1800/2186, Lower Bound:-245.95, Reconst:-231.36, KL:-14.59
# Epoch:17/100, Step:1900/2186, Lower Bound:-259.52, Reconst:-244.51, KL:-15.02
# Epoch:17/100, Step:2000/2186, Lower Bound:-242.36, Reconst:-226.66, KL:-15.70
# Epoch:17/100, Step:2100/2186, Lower Bound:-228.30, Reconst:-213.50, KL:-14.80
# Epoch:18/100, Step:100/2186, Lower Bound:-246.14, Reconst:-231.59, KL:-14.55
# Epoch:18/100, Step:200/2186, Lower Bound:-219.59, Reconst:-204.65, KL:-14.95
# Epoch:18/100, Step:300/2186, Lower Bound:-219.96, Reconst:-204.80, KL:-15.16
# Epoch:18/100, Step:400/2186, Lower Bound:-238.52, Reconst:-224.07, KL:-14.45
# Epoch:18/100, Step:500/2186, Lower Bound:-236.19, Reconst:-221.45, KL:-14.74
# Epoch:18/100, Step:600/2186, Lower Bound:-263.17, Reconst:-247.92, KL:-15.25
# Epoch:18/100, Step:700/2186, Lower Bound:-236.83, Reconst:-222.18, KL:-14.65
# Epoch:18/100, Step:800/2186, Lower Bound:-245.24, Reconst:-230.24, KL:-15.00
# Epoch:18/100, Step:900/2186, Lower Bound:-233.44, Reconst:-218.77, KL:-14.67
# Epoch:18/100, Step:1000/2186, Lower Bound:-227.42, Reconst:-212.61, KL:-14.80
# Epoch:18/100, Step:1100/2186, Lower Bound:-239.39, Reconst:-224.69, KL:-14.70
# Epoch:18/100, Step:1200/2186, Lower Bound:-247.40, Reconst:-232.83, KL:-14.58
# Epoch:18/100, Step:1300/2186, Lower Bound:-228.83, Reconst:-213.84, KL:-14.99
# Epoch:18/100, Step:1400/2186, Lower Bound:-220.93, Reconst:-206.72, KL:-14.21
# Epoch:18/100, Step:1500/2186, Lower Bound:-237.49, Reconst:-222.25, KL:-15.25
# Epoch:18/100, Step:1600/2186, Lower Bound:-254.71, Reconst:-239.76, KL:-14.95
# Epoch:18/100, Step:1700/2186, Lower Bound:-226.67, Reconst:-212.20, KL:-14.47
# Epoch:18/100, Step:1800/2186, Lower Bound:-268.28, Reconst:-252.93, KL:-15.35
# Epoch:18/100, Step:1900/2186, Lower Bound:-246.90, Reconst:-232.01, KL:-14.89
# Epoch:18/100, Step:2000/2186, Lower Bound:-267.74, Reconst:-252.90, KL:-14.84
# Epoch:18/100, Step:2100/2186, Lower Bound:-240.22, Reconst:-225.25, KL:-14.97
# Epoch:19/100, Step:100/2186, Lower Bound:-246.83, Reconst:-231.40, KL:-15.43
# Epoch:19/100, Step:200/2186, Lower Bound:-270.17, Reconst:-254.64, KL:-15.53
# Epoch:19/100, Step:300/2186, Lower Bound:-234.84, Reconst:-219.89, KL:-14.95
# Epoch:19/100, Step:400/2186, Lower Bound:-226.01, Reconst:-211.60, KL:-14.41
# Epoch:19/100, Step:500/2186, Lower Bound:-232.45, Reconst:-218.54, KL:-13.91
# Epoch:19/100, Step:600/2186, Lower Bound:-210.02, Reconst:-195.42, KL:-14.60
# Epoch:19/100, Step:700/2186, Lower Bound:-219.94, Reconst:-205.90, KL:-14.04
# Epoch:19/100, Step:800/2186, Lower Bound:-223.31, Reconst:-208.66, KL:-14.65
# Epoch:19/100, Step:900/2186, Lower Bound:-229.30, Reconst:-214.83, KL:-14.47
# Epoch:19/100, Step:1000/2186, Lower Bound:-222.67, Reconst:-207.31, KL:-15.36
# Epoch:19/100, Step:1100/2186, Lower Bound:-253.52, Reconst:-238.08, KL:-15.43
# Epoch:19/100, Step:1200/2186, Lower Bound:-246.21, Reconst:-231.22, KL:-14.99
# Epoch:19/100, Step:1300/2186, Lower Bound:-231.70, Reconst:-217.33, KL:-14.38
# Epoch:19/100, Step:1400/2186, Lower Bound:-257.45, Reconst:-242.54, KL:-14.91
# Epoch:19/100, Step:1500/2186, Lower Bound:-245.34, Reconst:-229.88, KL:-15.46
# Epoch:19/100, Step:1600/2186, Lower Bound:-237.48, Reconst:-223.04, KL:-14.44
# Epoch:19/100, Step:1700/2186, Lower Bound:-220.93, Reconst:-205.93, KL:-15.00
# Epoch:19/100, Step:1800/2186, Lower Bound:-245.79, Reconst:-230.90, KL:-14.89
# Epoch:19/100, Step:1900/2186, Lower Bound:-256.18, Reconst:-241.11, KL:-15.06
# Epoch:19/100, Step:2000/2186, Lower Bound:-221.17, Reconst:-206.97, KL:-14.20
# Epoch:19/100, Step:2100/2186, Lower Bound:-231.23, Reconst:-217.13, KL:-14.10
# Epoch:20/100, Step:100/2186, Lower Bound:-258.72, Reconst:-244.05, KL:-14.67
# Epoch:20/100, Step:200/2186, Lower Bound:-232.61, Reconst:-218.42, KL:-14.20
# Epoch:20/100, Step:300/2186, Lower Bound:-213.88, Reconst:-199.30, KL:-14.58
# Epoch:20/100, Step:400/2186, Lower Bound:-245.78, Reconst:-231.08, KL:-14.70
# Epoch:20/100, Step:500/2186, Lower Bound:-227.07, Reconst:-211.85, KL:-15.22
# Epoch:20/100, Step:600/2186, Lower Bound:-235.51, Reconst:-220.16, KL:-15.35
# Epoch:20/100, Step:700/2186, Lower Bound:-231.22, Reconst:-216.12, KL:-15.10
# Epoch:20/100, Step:800/2186, Lower Bound:-253.70, Reconst:-239.13, KL:-14.57
# Epoch:20/100, Step:900/2186, Lower Bound:-217.41, Reconst:-202.94, KL:-14.47
# Epoch:20/100, Step:1000/2186, Lower Bound:-236.13, Reconst:-221.72, KL:-14.41
# Epoch:20/100, Step:1100/2186, Lower Bound:-243.38, Reconst:-228.04, KL:-15.34
# Epoch:20/100, Step:1200/2186, Lower Bound:-244.90, Reconst:-229.58, KL:-15.32
# Epoch:20/100, Step:1300/2186, Lower Bound:-244.10, Reconst:-229.53, KL:-14.56
# Epoch:20/100, Step:1400/2186, Lower Bound:-242.61, Reconst:-228.14, KL:-14.47
# Epoch:20/100, Step:1500/2186, Lower Bound:-228.80, Reconst:-213.93, KL:-14.87
# Epoch:20/100, Step:1600/2186, Lower Bound:-240.08, Reconst:-224.88, KL:-15.20
# Epoch:20/100, Step:1700/2186, Lower Bound:-240.93, Reconst:-226.20, KL:-14.73
# Epoch:20/100, Step:1800/2186, Lower Bound:-229.92, Reconst:-215.03, KL:-14.89
# Epoch:20/100, Step:1900/2186, Lower Bound:-231.14, Reconst:-216.94, KL:-14.20
# Epoch:20/100, Step:2000/2186, Lower Bound:-240.70, Reconst:-226.60, KL:-14.10
# Epoch:20/100, Step:2100/2186, Lower Bound:-243.90, Reconst:-229.63, KL:-14.27
# Epoch:21/100, Step:100/2186, Lower Bound:-221.57, Reconst:-207.35, KL:-14.22
# Epoch:21/100, Step:200/2186, Lower Bound:-226.46, Reconst:-212.12, KL:-14.34
# Epoch:21/100, Step:300/2186, Lower Bound:-238.68, Reconst:-223.98, KL:-14.70
# Epoch:21/100, Step:400/2186, Lower Bound:-234.94, Reconst:-220.66, KL:-14.28
# Epoch:21/100, Step:500/2186, Lower Bound:-225.92, Reconst:-211.61, KL:-14.31
# Epoch:21/100, Step:600/2186, Lower Bound:-231.33, Reconst:-216.36, KL:-14.97
# Epoch:21/100, Step:700/2186, Lower Bound:-240.85, Reconst:-226.08, KL:-14.77
# Epoch:21/100, Step:800/2186, Lower Bound:-241.96, Reconst:-227.26, KL:-14.70
# Epoch:21/100, Step:900/2186, Lower Bound:-231.22, Reconst:-216.20, KL:-15.01
# Epoch:21/100, Step:1000/2186, Lower Bound:-235.50, Reconst:-221.20, KL:-14.30
# Epoch:21/100, Step:1100/2186, Lower Bound:-236.21, Reconst:-221.66, KL:-14.54
# Epoch:21/100, Step:1200/2186, Lower Bound:-239.96, Reconst:-225.41, KL:-14.55
# Epoch:21/100, Step:1300/2186, Lower Bound:-220.96, Reconst:-206.55, KL:-14.41
# Epoch:21/100, Step:1400/2186, Lower Bound:-235.01, Reconst:-219.85, KL:-15.15
# Epoch:21/100, Step:1500/2186, Lower Bound:-258.37, Reconst:-243.49, KL:-14.88
# Epoch:21/100, Step:1600/2186, Lower Bound:-218.47, Reconst:-204.02, KL:-14.45
# Epoch:21/100, Step:1700/2186, Lower Bound:-245.64, Reconst:-230.93, KL:-14.71
# Epoch:21/100, Step:1800/2186, Lower Bound:-252.82, Reconst:-237.41, KL:-15.41
# Epoch:21/100, Step:1900/2186, Lower Bound:-224.09, Reconst:-209.07, KL:-15.01
# Epoch:21/100, Step:2000/2186, Lower Bound:-238.71, Reconst:-224.02, KL:-14.69
# Epoch:21/100, Step:2100/2186, Lower Bound:-235.69, Reconst:-220.96, KL:-14.73
# Epoch:22/100, Step:100/2186, Lower Bound:-236.67, Reconst:-221.84, KL:-14.83
# Epoch:22/100, Step:200/2186, Lower Bound:-262.83, Reconst:-247.40, KL:-15.43
# Epoch:22/100, Step:300/2186, Lower Bound:-220.42, Reconst:-205.95, KL:-14.47
# Epoch:22/100, Step:400/2186, Lower Bound:-249.28, Reconst:-234.44, KL:-14.85
# Epoch:22/100, Step:500/2186, Lower Bound:-253.52, Reconst:-238.39, KL:-15.13
# Epoch:22/100, Step:600/2186, Lower Bound:-244.62, Reconst:-229.90, KL:-14.72
# Epoch:22/100, Step:700/2186, Lower Bound:-248.64, Reconst:-234.03, KL:-14.61
# Epoch:22/100, Step:800/2186, Lower Bound:-219.48, Reconst:-205.22, KL:-14.26
# Epoch:22/100, Step:900/2186, Lower Bound:-240.82, Reconst:-226.41, KL:-14.41
# Epoch:22/100, Step:1000/2186, Lower Bound:-224.51, Reconst:-210.04, KL:-14.47
# Epoch:22/100, Step:1100/2186, Lower Bound:-240.64, Reconst:-225.74, KL:-14.91
# Epoch:22/100, Step:1200/2186, Lower Bound:-212.21, Reconst:-197.58, KL:-14.63
# Epoch:22/100, Step:1300/2186, Lower Bound:-246.48, Reconst:-231.65, KL:-14.83
# Epoch:22/100, Step:1400/2186, Lower Bound:-248.43, Reconst:-233.13, KL:-15.31
# Epoch:22/100, Step:1500/2186, Lower Bound:-229.12, Reconst:-214.31, KL:-14.81
# Epoch:22/100, Step:1600/2186, Lower Bound:-229.52, Reconst:-215.46, KL:-14.06
# Epoch:22/100, Step:1700/2186, Lower Bound:-234.06, Reconst:-219.53, KL:-14.53
# Epoch:22/100, Step:1800/2186, Lower Bound:-252.55, Reconst:-237.85, KL:-14.70
# Epoch:22/100, Step:1900/2186, Lower Bound:-241.23, Reconst:-227.13, KL:-14.10
# Epoch:22/100, Step:2000/2186, Lower Bound:-233.33, Reconst:-219.09, KL:-14.24
# Epoch:22/100, Step:2100/2186, Lower Bound:-242.12, Reconst:-227.57, KL:-14.54
# Epoch:23/100, Step:100/2186, Lower Bound:-278.03, Reconst:-262.29, KL:-15.74
# Epoch:23/100, Step:200/2186, Lower Bound:-232.72, Reconst:-217.53, KL:-15.19
# Epoch:23/100, Step:300/2186, Lower Bound:-236.71, Reconst:-221.51, KL:-15.20
# Epoch:23/100, Step:400/2186, Lower Bound:-227.16, Reconst:-211.99, KL:-15.17
# Epoch:23/100, Step:500/2186, Lower Bound:-227.71, Reconst:-212.89, KL:-14.82
# Epoch:23/100, Step:600/2186, Lower Bound:-262.43, Reconst:-247.38, KL:-15.05
# Epoch:23/100, Step:700/2186, Lower Bound:-241.06, Reconst:-226.65, KL:-14.41
# Epoch:23/100, Step:800/2186, Lower Bound:-232.02, Reconst:-216.61, KL:-15.41
# Epoch:23/100, Step:900/2186, Lower Bound:-232.45, Reconst:-218.41, KL:-14.03
# Epoch:23/100, Step:1000/2186, Lower Bound:-271.54, Reconst:-256.17, KL:-15.37
# Epoch:23/100, Step:1100/2186, Lower Bound:-229.27, Reconst:-214.13, KL:-15.14
# Epoch:23/100, Step:1200/2186, Lower Bound:-232.30, Reconst:-217.60, KL:-14.71
# Epoch:23/100, Step:1300/2186, Lower Bound:-263.86, Reconst:-248.71, KL:-15.15
# Epoch:23/100, Step:1400/2186, Lower Bound:-229.08, Reconst:-214.95, KL:-14.13
# Epoch:23/100, Step:1500/2186, Lower Bound:-238.30, Reconst:-223.57, KL:-14.74
# Epoch:23/100, Step:1600/2186, Lower Bound:-234.58, Reconst:-219.99, KL:-14.59
# Epoch:23/100, Step:1700/2186, Lower Bound:-237.18, Reconst:-221.98, KL:-15.20
# Epoch:23/100, Step:1800/2186, Lower Bound:-245.26, Reconst:-229.91, KL:-15.35
# Epoch:23/100, Step:1900/2186, Lower Bound:-249.61, Reconst:-234.44, KL:-15.17
# Epoch:23/100, Step:2000/2186, Lower Bound:-245.21, Reconst:-229.76, KL:-15.46
# Epoch:23/100, Step:2100/2186, Lower Bound:-244.37, Reconst:-229.78, KL:-14.59
# Epoch:24/100, Step:100/2186, Lower Bound:-256.39, Reconst:-240.89, KL:-15.50
# Epoch:24/100, Step:200/2186, Lower Bound:-242.62, Reconst:-227.81, KL:-14.81
# Epoch:24/100, Step:300/2186, Lower Bound:-230.47, Reconst:-215.58, KL:-14.89
# Epoch:24/100, Step:400/2186, Lower Bound:-275.69, Reconst:-259.84, KL:-15.85
# Epoch:24/100, Step:500/2186, Lower Bound:-244.79, Reconst:-230.27, KL:-14.52
# Epoch:24/100, Step:600/2186, Lower Bound:-254.98, Reconst:-239.36, KL:-15.62
# Epoch:24/100, Step:700/2186, Lower Bound:-268.61, Reconst:-253.45, KL:-15.16
# Epoch:24/100, Step:800/2186, Lower Bound:-266.61, Reconst:-251.70, KL:-14.90
# Epoch:24/100, Step:900/2186, Lower Bound:-233.18, Reconst:-218.11, KL:-15.07
# Epoch:24/100, Step:1000/2186, Lower Bound:-223.32, Reconst:-208.51, KL:-14.81
# Epoch:24/100, Step:1100/2186, Lower Bound:-240.79, Reconst:-225.56, KL:-15.23
# Epoch:24/100, Step:1200/2186, Lower Bound:-266.24, Reconst:-251.21, KL:-15.03
# Epoch:24/100, Step:1300/2186, Lower Bound:-266.84, Reconst:-251.49, KL:-15.35
# Epoch:24/100, Step:1400/2186, Lower Bound:-202.90, Reconst:-188.25, KL:-14.66
# Epoch:24/100, Step:1500/2186, Lower Bound:-241.16, Reconst:-226.69, KL:-14.47
# Epoch:24/100, Step:1600/2186, Lower Bound:-234.30, Reconst:-219.81, KL:-14.48
# Epoch:24/100, Step:1700/2186, Lower Bound:-243.56, Reconst:-228.68, KL:-14.88
# Epoch:24/100, Step:1800/2186, Lower Bound:-251.55, Reconst:-236.94, KL:-14.62
# Epoch:24/100, Step:1900/2186, Lower Bound:-247.35, Reconst:-232.32, KL:-15.03
# Epoch:24/100, Step:2000/2186, Lower Bound:-259.62, Reconst:-244.37, KL:-15.25
# Epoch:24/100, Step:2100/2186, Lower Bound:-260.15, Reconst:-246.11, KL:-14.04
# Epoch:25/100, Step:100/2186, Lower Bound:-238.41, Reconst:-224.04, KL:-14.37
# Epoch:25/100, Step:200/2186, Lower Bound:-240.95, Reconst:-226.53, KL:-14.42
# Epoch:25/100, Step:300/2186, Lower Bound:-251.66, Reconst:-236.97, KL:-14.69
# Epoch:25/100, Step:400/2186, Lower Bound:-250.88, Reconst:-236.21, KL:-14.66
# Epoch:25/100, Step:500/2186, Lower Bound:-238.47, Reconst:-223.99, KL:-14.48
# Epoch:25/100, Step:600/2186, Lower Bound:-250.21, Reconst:-235.45, KL:-14.76
# Epoch:25/100, Step:700/2186, Lower Bound:-275.66, Reconst:-260.74, KL:-14.93
# Epoch:25/100, Step:800/2186, Lower Bound:-224.44, Reconst:-209.00, KL:-15.44
# Epoch:25/100, Step:900/2186, Lower Bound:-260.66, Reconst:-245.57, KL:-15.09
# Epoch:25/100, Step:1000/2186, Lower Bound:-228.67, Reconst:-213.83, KL:-14.84
# Epoch:25/100, Step:1100/2186, Lower Bound:-242.94, Reconst:-227.82, KL:-15.12
# Epoch:25/100, Step:1200/2186, Lower Bound:-213.12, Reconst:-198.72, KL:-14.40
# Epoch:25/100, Step:1300/2186, Lower Bound:-235.92, Reconst:-221.29, KL:-14.63
# Epoch:25/100, Step:1400/2186, Lower Bound:-256.80, Reconst:-242.27, KL:-14.53
# Epoch:25/100, Step:1500/2186, Lower Bound:-226.45, Reconst:-211.74, KL:-14.71
# Epoch:25/100, Step:1600/2186, Lower Bound:-224.59, Reconst:-210.09, KL:-14.51
# Epoch:25/100, Step:1700/2186, Lower Bound:-237.45, Reconst:-223.05, KL:-14.41
# Epoch:25/100, Step:1800/2186, Lower Bound:-234.64, Reconst:-219.99, KL:-14.65
# Epoch:25/100, Step:1900/2186, Lower Bound:-231.62, Reconst:-216.26, KL:-15.37
# Epoch:25/100, Step:2000/2186, Lower Bound:-258.58, Reconst:-242.93, KL:-15.65
# Epoch:25/100, Step:2100/2186, Lower Bound:-259.82, Reconst:-244.88, KL:-14.94
# Epoch:26/100, Step:100/2186, Lower Bound:-262.03, Reconst:-246.79, KL:-15.24
# Epoch:26/100, Step:200/2186, Lower Bound:-260.74, Reconst:-245.26, KL:-15.48
# Epoch:26/100, Step:300/2186, Lower Bound:-227.71, Reconst:-213.56, KL:-14.15
# Epoch:26/100, Step:400/2186, Lower Bound:-260.26, Reconst:-245.46, KL:-14.81
# Epoch:26/100, Step:500/2186, Lower Bound:-215.37, Reconst:-201.00, KL:-14.37
# Epoch:26/100, Step:600/2186, Lower Bound:-229.14, Reconst:-214.86, KL:-14.28
# Epoch:26/100, Step:700/2186, Lower Bound:-261.54, Reconst:-246.35, KL:-15.19
# Epoch:26/100, Step:800/2186, Lower Bound:-243.20, Reconst:-228.63, KL:-14.57
# Epoch:26/100, Step:900/2186, Lower Bound:-250.05, Reconst:-235.04, KL:-15.01
# Epoch:26/100, Step:1000/2186, Lower Bound:-229.15, Reconst:-214.14, KL:-15.01
# Epoch:26/100, Step:1100/2186, Lower Bound:-244.57, Reconst:-229.05, KL:-15.52
# Epoch:26/100, Step:1200/2186, Lower Bound:-243.77, Reconst:-228.87, KL:-14.90
# Epoch:26/100, Step:1300/2186, Lower Bound:-261.14, Reconst:-246.00, KL:-15.14
# Epoch:26/100, Step:1400/2186, Lower Bound:-247.71, Reconst:-232.56, KL:-15.15
# Epoch:26/100, Step:1500/2186, Lower Bound:-254.22, Reconst:-239.36, KL:-14.86
# Epoch:26/100, Step:1600/2186, Lower Bound:-234.72, Reconst:-219.91, KL:-14.80
# Epoch:26/100, Step:1700/2186, Lower Bound:-255.33, Reconst:-240.25, KL:-15.08
# Epoch:26/100, Step:1800/2186, Lower Bound:-228.38, Reconst:-213.56, KL:-14.82
# Epoch:26/100, Step:1900/2186, Lower Bound:-248.82, Reconst:-234.03, KL:-14.79
# Epoch:26/100, Step:2000/2186, Lower Bound:-242.95, Reconst:-228.18, KL:-14.77
# Epoch:26/100, Step:2100/2186, Lower Bound:-230.72, Reconst:-216.43, KL:-14.30
# Epoch:27/100, Step:100/2186, Lower Bound:-258.82, Reconst:-243.27, KL:-15.56
# Epoch:27/100, Step:200/2186, Lower Bound:-220.43, Reconst:-205.57, KL:-14.86
# Epoch:27/100, Step:300/2186, Lower Bound:-258.40, Reconst:-243.22, KL:-15.18
# Epoch:27/100, Step:400/2186, Lower Bound:-218.93, Reconst:-204.99, KL:-13.94
# Epoch:27/100, Step:500/2186, Lower Bound:-240.66, Reconst:-225.35, KL:-15.31
# Epoch:27/100, Step:600/2186, Lower Bound:-253.28, Reconst:-238.11, KL:-15.17
# Epoch:27/100, Step:700/2186, Lower Bound:-265.02, Reconst:-249.75, KL:-15.27
# Epoch:27/100, Step:800/2186, Lower Bound:-244.21, Reconst:-229.52, KL:-14.70
# Epoch:27/100, Step:900/2186, Lower Bound:-217.72, Reconst:-203.35, KL:-14.37
# Epoch:27/100, Step:1000/2186, Lower Bound:-240.32, Reconst:-225.68, KL:-14.65
# Epoch:27/100, Step:1100/2186, Lower Bound:-227.00, Reconst:-212.48, KL:-14.52
# Epoch:27/100, Step:1200/2186, Lower Bound:-261.77, Reconst:-246.95, KL:-14.82
# Epoch:27/100, Step:1300/2186, Lower Bound:-204.98, Reconst:-190.33, KL:-14.64
# Epoch:27/100, Step:1400/2186, Lower Bound:-230.62, Reconst:-215.97, KL:-14.65
# Epoch:27/100, Step:1500/2186, Lower Bound:-206.33, Reconst:-191.81, KL:-14.52
# Epoch:27/100, Step:1600/2186, Lower Bound:-232.95, Reconst:-218.27, KL:-14.67
# Epoch:27/100, Step:1700/2186, Lower Bound:-252.53, Reconst:-238.26, KL:-14.28
# Epoch:27/100, Step:1800/2186, Lower Bound:-237.97, Reconst:-222.76, KL:-15.22
# Epoch:27/100, Step:1900/2186, Lower Bound:-233.45, Reconst:-218.84, KL:-14.60
# Epoch:27/100, Step:2000/2186, Lower Bound:-244.67, Reconst:-229.56, KL:-15.11
# Epoch:27/100, Step:2100/2186, Lower Bound:-236.47, Reconst:-222.48, KL:-13.99
# Epoch:28/100, Step:100/2186, Lower Bound:-248.18, Reconst:-234.02, KL:-14.16
# Epoch:28/100, Step:200/2186, Lower Bound:-225.49, Reconst:-210.53, KL:-14.96
# Epoch:28/100, Step:300/2186, Lower Bound:-210.99, Reconst:-196.24, KL:-14.75
# Epoch:28/100, Step:400/2186, Lower Bound:-239.10, Reconst:-224.51, KL:-14.59
# Epoch:28/100, Step:500/2186, Lower Bound:-239.83, Reconst:-225.19, KL:-14.64
# Epoch:28/100, Step:600/2186, Lower Bound:-226.60, Reconst:-212.65, KL:-13.95
# Epoch:28/100, Step:700/2186, Lower Bound:-222.98, Reconst:-208.59, KL:-14.39
# Epoch:28/100, Step:800/2186, Lower Bound:-228.37, Reconst:-213.85, KL:-14.52
# Epoch:28/100, Step:900/2186, Lower Bound:-239.80, Reconst:-224.83, KL:-14.97
# Epoch:28/100, Step:1000/2186, Lower Bound:-222.30, Reconst:-208.34, KL:-13.96
# Epoch:28/100, Step:1100/2186, Lower Bound:-224.10, Reconst:-210.06, KL:-14.04
# Epoch:28/100, Step:1200/2186, Lower Bound:-251.48, Reconst:-236.12, KL:-15.36
# Epoch:28/100, Step:1300/2186, Lower Bound:-224.23, Reconst:-209.84, KL:-14.40
# Epoch:28/100, Step:1400/2186, Lower Bound:-226.85, Reconst:-211.95, KL:-14.90
# Epoch:28/100, Step:1500/2186, Lower Bound:-251.97, Reconst:-237.35, KL:-14.61
# Epoch:28/100, Step:1600/2186, Lower Bound:-269.07, Reconst:-253.53, KL:-15.54
# Epoch:28/100, Step:1700/2186, Lower Bound:-265.27, Reconst:-250.39, KL:-14.88
# Epoch:28/100, Step:1800/2186, Lower Bound:-247.30, Reconst:-232.63, KL:-14.67
# Epoch:28/100, Step:1900/2186, Lower Bound:-236.71, Reconst:-222.04, KL:-14.67
# Epoch:28/100, Step:2000/2186, Lower Bound:-248.99, Reconst:-233.48, KL:-15.51
# Epoch:28/100, Step:2100/2186, Lower Bound:-226.99, Reconst:-212.19, KL:-14.79
# Epoch:29/100, Step:100/2186, Lower Bound:-254.89, Reconst:-239.55, KL:-15.33
# Epoch:29/100, Step:200/2186, Lower Bound:-217.14, Reconst:-202.40, KL:-14.74
# Epoch:29/100, Step:300/2186, Lower Bound:-217.23, Reconst:-202.60, KL:-14.63
# Epoch:29/100, Step:400/2186, Lower Bound:-227.44, Reconst:-212.71, KL:-14.73
# Epoch:29/100, Step:500/2186, Lower Bound:-220.05, Reconst:-205.97, KL:-14.07
# Epoch:29/100, Step:600/2186, Lower Bound:-258.00, Reconst:-243.06, KL:-14.94
# Epoch:29/100, Step:700/2186, Lower Bound:-233.99, Reconst:-218.80, KL:-15.18
# Epoch:29/100, Step:800/2186, Lower Bound:-235.50, Reconst:-220.08, KL:-15.42
# Epoch:29/100, Step:900/2186, Lower Bound:-235.27, Reconst:-220.87, KL:-14.40
# Epoch:29/100, Step:1000/2186, Lower Bound:-252.58, Reconst:-236.86, KL:-15.72
# Epoch:29/100, Step:1100/2186, Lower Bound:-229.38, Reconst:-214.56, KL:-14.82
# Epoch:29/100, Step:1200/2186, Lower Bound:-245.12, Reconst:-230.28, KL:-14.83
# Epoch:29/100, Step:1300/2186, Lower Bound:-248.45, Reconst:-233.68, KL:-14.77
# Epoch:29/100, Step:1400/2186, Lower Bound:-235.08, Reconst:-220.77, KL:-14.31
# Epoch:29/100, Step:1500/2186, Lower Bound:-237.87, Reconst:-222.75, KL:-15.12
# Epoch:29/100, Step:1600/2186, Lower Bound:-250.95, Reconst:-236.10, KL:-14.85
# Epoch:29/100, Step:1700/2186, Lower Bound:-259.46, Reconst:-244.45, KL:-15.01
# Epoch:29/100, Step:1800/2186, Lower Bound:-251.27, Reconst:-236.63, KL:-14.64
# Epoch:29/100, Step:1900/2186, Lower Bound:-240.36, Reconst:-225.35, KL:-15.01
# Epoch:29/100, Step:2000/2186, Lower Bound:-239.82, Reconst:-224.87, KL:-14.95
# Epoch:29/100, Step:2100/2186, Lower Bound:-229.31, Reconst:-214.66, KL:-14.65
# Epoch:30/100, Step:100/2186, Lower Bound:-214.92, Reconst:-200.34, KL:-14.58
# Epoch:30/100, Step:200/2186, Lower Bound:-224.79, Reconst:-210.43, KL:-14.36
# Epoch:30/100, Step:300/2186, Lower Bound:-242.70, Reconst:-227.42, KL:-15.28
# Epoch:30/100, Step:400/2186, Lower Bound:-232.02, Reconst:-217.50, KL:-14.52
# Epoch:30/100, Step:500/2186, Lower Bound:-238.54, Reconst:-224.08, KL:-14.46
# Epoch:30/100, Step:600/2186, Lower Bound:-242.82, Reconst:-228.15, KL:-14.68
# Epoch:30/100, Step:700/2186, Lower Bound:-231.60, Reconst:-217.00, KL:-14.60
# Epoch:30/100, Step:800/2186, Lower Bound:-241.28, Reconst:-226.27, KL:-15.01
# Epoch:30/100, Step:900/2186, Lower Bound:-247.84, Reconst:-232.32, KL:-15.52
# Epoch:30/100, Step:1000/2186, Lower Bound:-240.19, Reconst:-225.47, KL:-14.72
# Epoch:30/100, Step:1100/2186, Lower Bound:-249.75, Reconst:-234.14, KL:-15.61
# Epoch:30/100, Step:1200/2186, Lower Bound:-222.59, Reconst:-208.33, KL:-14.26
# ...
# Epoch:91/100, Step:600/2186, Lower Bound:-196.69, Reconst:-181.84, KL:-14.85
# Epoch:91/100, Step:700/2186, Lower Bound:-241.29, Reconst:-226.28, KL:-15.01
# Epoch:91/100, Step:800/2186, Lower Bound:-217.36, Reconst:-203.49, KL:-13.87
# Epoch:91/100, Step:900/2186, Lower Bound:-233.87, Reconst:-219.90, KL:-13.98
# Epoch:91/100, Step:1000/2186, Lower Bound:-241.88, Reconst:-227.48, KL:-14.40
# Epoch:91/100, Step:1100/2186, Lower Bound:-238.38, Reconst:-223.39, KL:-15.00
# Epoch:91/100, Step:1200/2186, Lower Bound:-225.75, Reconst:-210.62, KL:-15.13
# Epoch:91/100, Step:1300/2186, Lower Bound:-244.83, Reconst:-229.61, KL:-15.22
# Epoch:91/100, Step:1400/2186, Lower Bound:-225.62, Reconst:-210.54, KL:-15.08
# Epoch:91/100, Step:1500/2186, Lower Bound:-237.19, Reconst:-222.16, KL:-15.03
# Epoch:91/100, Step:1600/2186, Lower Bound:-248.32, Reconst:-233.33, KL:-15.00
# Epoch:91/100, Step:1700/2186, Lower Bound:-246.26, Reconst:-230.26, KL:-16.00
# Epoch:91/100, Step:1800/2186, Lower Bound:-231.26, Reconst:-216.63, KL:-14.64
# Epoch:91/100, Step:1900/2186, Lower Bound:-229.21, Reconst:-214.06, KL:-15.15
# Epoch:91/100, Step:2000/2186, Lower Bound:-252.11, Reconst:-236.13, KL:-15.97
# Epoch:91/100, Step:2100/2186, Lower Bound:-242.71, Reconst:-228.19, KL:-14.52
# Epoch:92/100, Step:100/2186, Lower Bound:-216.79, Reconst:-201.96, KL:-14.84
# Epoch:92/100, Step:200/2186, Lower Bound:-228.62, Reconst:-213.95, KL:-14.68
# Epoch:92/100, Step:300/2186, Lower Bound:-214.70, Reconst:-199.87, KL:-14.83
# Epoch:92/100, Step:400/2186, Lower Bound:-232.72, Reconst:-217.42, KL:-15.30
# Epoch:92/100, Step:500/2186, Lower Bound:-255.52, Reconst:-240.23, KL:-15.29
# Epoch:92/100, Step:600/2186, Lower Bound:-257.09, Reconst:-241.73, KL:-15.36
# Epoch:92/100, Step:700/2186, Lower Bound:-233.58, Reconst:-218.95, KL:-14.63
# Epoch:92/100, Step:800/2186, Lower Bound:-229.62, Reconst:-214.64, KL:-14.98
# Epoch:92/100, Step:900/2186, Lower Bound:-249.18, Reconst:-234.29, KL:-14.88
# Epoch:92/100, Step:1000/2186, Lower Bound:-254.26, Reconst:-238.74, KL:-15.51
# Epoch:92/100, Step:1100/2186, Lower Bound:-238.17, Reconst:-222.95, KL:-15.22
# Epoch:92/100, Step:1200/2186, Lower Bound:-218.26, Reconst:-203.17, KL:-15.09
# Epoch:92/100, Step:1300/2186, Lower Bound:-240.06, Reconst:-224.58, KL:-15.48
# Epoch:92/100, Step:1400/2186, Lower Bound:-226.92, Reconst:-212.02, KL:-14.90
# Epoch:92/100, Step:1500/2186, Lower Bound:-229.98, Reconst:-215.04, KL:-14.94
# Epoch:92/100, Step:1600/2186, Lower Bound:-227.31, Reconst:-212.35, KL:-14.96
# Epoch:92/100, Step:1700/2186, Lower Bound:-243.83, Reconst:-229.02, KL:-14.81
# Epoch:92/100, Step:1800/2186, Lower Bound:-225.34, Reconst:-209.89, KL:-15.44
# Epoch:92/100, Step:1900/2186, Lower Bound:-245.14, Reconst:-230.21, KL:-14.93
# Epoch:92/100, Step:2000/2186, Lower Bound:-207.68, Reconst:-193.09, KL:-14.59
# Epoch:92/100, Step:2100/2186, Lower Bound:-257.11, Reconst:-241.78, KL:-15.34
# Epoch:93/100, Step:100/2186, Lower Bound:-243.38, Reconst:-228.44, KL:-14.94
# Epoch:93/100, Step:200/2186, Lower Bound:-237.20, Reconst:-221.83, KL:-15.37
# Epoch:93/100, Step:300/2186, Lower Bound:-237.98, Reconst:-223.44, KL:-14.54
# Epoch:93/100, Step:400/2186, Lower Bound:-233.97, Reconst:-219.04, KL:-14.93
# Epoch:93/100, Step:500/2186, Lower Bound:-230.88, Reconst:-215.94, KL:-14.93
# Epoch:93/100, Step:600/2186, Lower Bound:-221.50, Reconst:-205.91, KL:-15.60
# Epoch:93/100, Step:700/2186, Lower Bound:-264.28, Reconst:-248.30, KL:-15.98
# Epoch:93/100, Step:800/2186, Lower Bound:-219.17, Reconst:-204.61, KL:-14.57
# Epoch:93/100, Step:900/2186, Lower Bound:-224.94, Reconst:-209.62, KL:-15.32
# Epoch:93/100, Step:1000/2186, Lower Bound:-217.65, Reconst:-202.59, KL:-15.06
# Epoch:93/100, Step:1100/2186, Lower Bound:-237.16, Reconst:-222.17, KL:-14.98
# Epoch:93/100, Step:1200/2186, Lower Bound:-246.36, Reconst:-230.79, KL:-15.57
# Epoch:93/100, Step:1300/2186, Lower Bound:-223.46, Reconst:-209.39, KL:-14.07
# Epoch:93/100, Step:1400/2186, Lower Bound:-223.04, Reconst:-208.21, KL:-14.83
# Epoch:93/100, Step:1500/2186, Lower Bound:-250.84, Reconst:-235.35, KL:-15.49
# Epoch:93/100, Step:1600/2186, Lower Bound:-215.57, Reconst:-200.87, KL:-14.70
# Epoch:93/100, Step:1700/2186, Lower Bound:-224.34, Reconst:-209.27, KL:-15.07
# Epoch:93/100, Step:1800/2186, Lower Bound:-233.92, Reconst:-218.62, KL:-15.29
# Epoch:93/100, Step:1900/2186, Lower Bound:-232.72, Reconst:-217.89, KL:-14.83
# Epoch:93/100, Step:2000/2186, Lower Bound:-239.26, Reconst:-225.05, KL:-14.21
# Epoch:93/100, Step:2100/2186, Lower Bound:-244.53, Reconst:-229.71, KL:-14.82
# Epoch:94/100, Step:100/2186, Lower Bound:-243.65, Reconst:-228.33, KL:-15.32
# Epoch:94/100, Step:200/2186, Lower Bound:-248.77, Reconst:-232.95, KL:-15.82
# Epoch:94/100, Step:300/2186, Lower Bound:-204.52, Reconst:-189.91, KL:-14.61
# Epoch:94/100, Step:400/2186, Lower Bound:-225.15, Reconst:-210.91, KL:-14.24
# Epoch:94/100, Step:500/2186, Lower Bound:-244.96, Reconst:-230.23, KL:-14.73
# Epoch:94/100, Step:600/2186, Lower Bound:-242.80, Reconst:-227.81, KL:-14.99
# Epoch:94/100, Step:700/2186, Lower Bound:-236.15, Reconst:-221.32, KL:-14.83
# Epoch:94/100, Step:800/2186, Lower Bound:-228.20, Reconst:-213.62, KL:-14.58
# Epoch:94/100, Step:900/2186, Lower Bound:-235.47, Reconst:-221.07, KL:-14.40
# Epoch:94/100, Step:1000/2186, Lower Bound:-232.66, Reconst:-217.14, KL:-15.52
# Epoch:94/100, Step:1100/2186, Lower Bound:-252.45, Reconst:-238.04, KL:-14.41
# Epoch:94/100, Step:1200/2186, Lower Bound:-209.54, Reconst:-194.21, KL:-15.33
# Epoch:94/100, Step:1300/2186, Lower Bound:-238.00, Reconst:-223.41, KL:-14.59
# Epoch:94/100, Step:1400/2186, Lower Bound:-225.96, Reconst:-211.16, KL:-14.80
# Epoch:94/100, Step:1500/2186, Lower Bound:-233.41, Reconst:-218.71, KL:-14.69
# Epoch:94/100, Step:1600/2186, Lower Bound:-230.27, Reconst:-215.66, KL:-14.61
# Epoch:94/100, Step:1700/2186, Lower Bound:-231.24, Reconst:-216.79, KL:-14.45
# Epoch:94/100, Step:1800/2186, Lower Bound:-253.72, Reconst:-239.23, KL:-14.50
# Epoch:94/100, Step:1900/2186, Lower Bound:-243.14, Reconst:-228.17, KL:-14.97
# Epoch:94/100, Step:2000/2186, Lower Bound:-249.54, Reconst:-235.00, KL:-14.54
# Epoch:94/100, Step:2100/2186, Lower Bound:-250.78, Reconst:-235.53, KL:-15.25
# Epoch:95/100, Step:100/2186, Lower Bound:-252.37, Reconst:-236.93, KL:-15.44
# Epoch:95/100, Step:200/2186, Lower Bound:-244.47, Reconst:-229.76, KL:-14.71
# Epoch:95/100, Step:300/2186, Lower Bound:-237.89, Reconst:-222.63, KL:-15.26
# Epoch:95/100, Step:400/2186, Lower Bound:-246.65, Reconst:-231.68, KL:-14.96
# Epoch:95/100, Step:500/2186, Lower Bound:-239.53, Reconst:-225.11, KL:-14.42
# Epoch:95/100, Step:600/2186, Lower Bound:-222.77, Reconst:-207.83, KL:-14.94
# Epoch:95/100, Step:700/2186, Lower Bound:-222.08, Reconst:-206.61, KL:-15.47
# Epoch:95/100, Step:800/2186, Lower Bound:-238.05, Reconst:-222.68, KL:-15.37
# Epoch:95/100, Step:900/2186, Lower Bound:-252.14, Reconst:-236.14, KL:-16.01
# Epoch:95/100, Step:1000/2186, Lower Bound:-255.10, Reconst:-239.90, KL:-15.19
# Epoch:95/100, Step:1100/2186, Lower Bound:-236.88, Reconst:-222.32, KL:-14.56
# Epoch:95/100, Step:1200/2186, Lower Bound:-227.40, Reconst:-213.40, KL:-14.00
# Epoch:95/100, Step:1300/2186, Lower Bound:-241.61, Reconst:-226.31, KL:-15.30
# Epoch:95/100, Step:1400/2186, Lower Bound:-245.97, Reconst:-230.08, KL:-15.88
# Epoch:95/100, Step:1500/2186, Lower Bound:-246.95, Reconst:-232.59, KL:-14.35
# Epoch:95/100, Step:1600/2186, Lower Bound:-216.43, Reconst:-201.73, KL:-14.71
# Epoch:95/100, Step:1700/2186, Lower Bound:-213.26, Reconst:-198.21, KL:-15.06
# Epoch:95/100, Step:1800/2186, Lower Bound:-226.19, Reconst:-211.29, KL:-14.90
# Epoch:95/100, Step:1900/2186, Lower Bound:-236.92, Reconst:-221.91, KL:-15.01
# Epoch:95/100, Step:2000/2186, Lower Bound:-233.87, Reconst:-218.80, KL:-15.07
# Epoch:95/100, Step:2100/2186, Lower Bound:-234.00, Reconst:-218.82, KL:-15.19
# Epoch:96/100, Step:100/2186, Lower Bound:-241.14, Reconst:-225.97, KL:-15.17
# Epoch:96/100, Step:200/2186, Lower Bound:-213.66, Reconst:-197.96, KL:-15.70
# Epoch:96/100, Step:300/2186, Lower Bound:-228.73, Reconst:-213.26, KL:-15.47
# Epoch:96/100, Step:400/2186, Lower Bound:-216.00, Reconst:-200.56, KL:-15.44
# Epoch:96/100, Step:500/2186, Lower Bound:-233.20, Reconst:-218.61, KL:-14.58
# Epoch:96/100, Step:600/2186, Lower Bound:-229.48, Reconst:-215.37, KL:-14.11
# Epoch:96/100, Step:700/2186, Lower Bound:-228.01, Reconst:-213.53, KL:-14.48
# Epoch:96/100, Step:800/2186, Lower Bound:-227.02, Reconst:-212.63, KL:-14.39
# Epoch:96/100, Step:900/2186, Lower Bound:-248.21, Reconst:-233.17, KL:-15.04
# Epoch:96/100, Step:1000/2186, Lower Bound:-218.54, Reconst:-203.94, KL:-14.60
# Epoch:96/100, Step:1100/2186, Lower Bound:-254.14, Reconst:-239.36, KL:-14.78
# Epoch:96/100, Step:1200/2186, Lower Bound:-256.08, Reconst:-240.84, KL:-15.24
# Epoch:96/100, Step:1300/2186, Lower Bound:-242.59, Reconst:-227.80, KL:-14.79
# Epoch:96/100, Step:1400/2186, Lower Bound:-239.01, Reconst:-223.99, KL:-15.02
# Epoch:96/100, Step:1500/2186, Lower Bound:-258.12, Reconst:-242.67, KL:-15.45
# Epoch:96/100, Step:1600/2186, Lower Bound:-234.31, Reconst:-219.57, KL:-14.74
# Epoch:96/100, Step:1700/2186, Lower Bound:-226.68, Reconst:-212.21, KL:-14.48
# Epoch:96/100, Step:1800/2186, Lower Bound:-239.14, Reconst:-224.31, KL:-14.83
# Epoch:96/100, Step:1900/2186, Lower Bound:-238.74, Reconst:-224.51, KL:-14.22
# Epoch:96/100, Step:2000/2186, Lower Bound:-227.29, Reconst:-211.93, KL:-15.36
# Epoch:96/100, Step:2100/2186, Lower Bound:-232.99, Reconst:-218.25, KL:-14.74
# Epoch:97/100, Step:100/2186, Lower Bound:-256.86, Reconst:-241.32, KL:-15.54
# Epoch:97/100, Step:200/2186, Lower Bound:-215.91, Reconst:-201.49, KL:-14.43
# Epoch:97/100, Step:300/2186, Lower Bound:-254.73, Reconst:-239.63, KL:-15.10
# Epoch:97/100, Step:400/2186, Lower Bound:-257.45, Reconst:-242.28, KL:-15.17
# Epoch:97/100, Step:500/2186, Lower Bound:-224.16, Reconst:-209.07, KL:-15.10
# Epoch:97/100, Step:600/2186, Lower Bound:-247.18, Reconst:-232.33, KL:-14.85
# Epoch:97/100, Step:700/2186, Lower Bound:-225.74, Reconst:-210.88, KL:-14.86
# Epoch:97/100, Step:800/2186, Lower Bound:-220.98, Reconst:-206.02, KL:-14.96
# Epoch:97/100, Step:900/2186, Lower Bound:-238.22, Reconst:-222.78, KL:-15.44
# Epoch:97/100, Step:1000/2186, Lower Bound:-227.45, Reconst:-212.34, KL:-15.11
# Epoch:97/100, Step:1100/2186, Lower Bound:-258.48, Reconst:-243.06, KL:-15.42
# Epoch:97/100, Step:1200/2186, Lower Bound:-232.04, Reconst:-216.95, KL:-15.09
# Epoch:97/100, Step:1300/2186, Lower Bound:-232.11, Reconst:-217.47, KL:-14.65
# Epoch:97/100, Step:1400/2186, Lower Bound:-233.74, Reconst:-218.84, KL:-14.90
# Epoch:97/100, Step:1500/2186, Lower Bound:-223.80, Reconst:-209.04, KL:-14.76
# Epoch:97/100, Step:1600/2186, Lower Bound:-231.27, Reconst:-216.52, KL:-14.75
# Epoch:97/100, Step:1700/2186, Lower Bound:-218.00, Reconst:-202.91, KL:-15.08
# Epoch:97/100, Step:1800/2186, Lower Bound:-242.78, Reconst:-227.87, KL:-14.90
# Epoch:97/100, Step:1900/2186, Lower Bound:-245.28, Reconst:-229.88, KL:-15.40
# Epoch:97/100, Step:2000/2186, Lower Bound:-241.93, Reconst:-227.53, KL:-14.40
# Epoch:97/100, Step:2100/2186, Lower Bound:-240.29, Reconst:-225.36, KL:-14.93
# Epoch:98/100, Step:100/2186, Lower Bound:-253.92, Reconst:-238.42, KL:-15.50
# Epoch:98/100, Step:200/2186, Lower Bound:-222.34, Reconst:-207.11, KL:-15.23
# Epoch:98/100, Step:300/2186, Lower Bound:-241.28, Reconst:-226.10, KL:-15.18
# Epoch:98/100, Step:400/2186, Lower Bound:-255.44, Reconst:-240.33, KL:-15.11
# Epoch:98/100, Step:500/2186, Lower Bound:-249.05, Reconst:-233.69, KL:-15.36
# Epoch:98/100, Step:600/2186, Lower Bound:-250.60, Reconst:-235.69, KL:-14.91
# Epoch:98/100, Step:700/2186, Lower Bound:-229.16, Reconst:-214.62, KL:-14.55
# Epoch:98/100, Step:800/2186, Lower Bound:-253.83, Reconst:-238.72, KL:-15.11
# Epoch:98/100, Step:900/2186, Lower Bound:-250.38, Reconst:-235.20, KL:-15.18
# Epoch:98/100, Step:1000/2186, Lower Bound:-244.79, Reconst:-229.14, KL:-15.65
# Epoch:98/100, Step:1100/2186, Lower Bound:-231.85, Reconst:-216.88, KL:-14.97
# Epoch:98/100, Step:1200/2186, Lower Bound:-235.82, Reconst:-221.28, KL:-14.54
# Epoch:98/100, Step:1300/2186, Lower Bound:-237.39, Reconst:-222.48, KL:-14.91
# Epoch:98/100, Step:1400/2186, Lower Bound:-238.11, Reconst:-222.91, KL:-15.21
# Epoch:98/100, Step:1500/2186, Lower Bound:-248.47, Reconst:-233.70, KL:-14.77
# Epoch:98/100, Step:1600/2186, Lower Bound:-240.86, Reconst:-225.43, KL:-15.43
# Epoch:98/100, Step:1700/2186, Lower Bound:-230.88, Reconst:-216.08, KL:-14.80
# Epoch:98/100, Step:1800/2186, Lower Bound:-225.96, Reconst:-211.51, KL:-14.45
# Epoch:98/100, Step:1900/2186, Lower Bound:-231.32, Reconst:-216.67, KL:-14.65
# Epoch:98/100, Step:2000/2186, Lower Bound:-264.95, Reconst:-249.39, KL:-15.57
# Epoch:98/100, Step:2100/2186, Lower Bound:-250.47, Reconst:-235.62, KL:-14.85
# Epoch:99/100, Step:100/2186, Lower Bound:-227.56, Reconst:-213.08, KL:-14.47
# Epoch:99/100, Step:200/2186, Lower Bound:-270.25, Reconst:-254.59, KL:-15.66
# Epoch:99/100, Step:300/2186, Lower Bound:-228.83, Reconst:-213.97, KL:-14.86
# Epoch:99/100, Step:400/2186, Lower Bound:-247.19, Reconst:-230.84, KL:-16.36
# Epoch:99/100, Step:500/2186, Lower Bound:-247.13, Reconst:-232.63, KL:-14.51
# Epoch:99/100, Step:600/2186, Lower Bound:-216.44, Reconst:-201.88, KL:-14.56
# Epoch:99/100, Step:700/2186, Lower Bound:-231.19, Reconst:-215.50, KL:-15.69
# Epoch:99/100, Step:800/2186, Lower Bound:-236.41, Reconst:-221.17, KL:-15.23
# Epoch:99/100, Step:900/2186, Lower Bound:-223.58, Reconst:-209.19, KL:-14.40
# Epoch:99/100, Step:1000/2186, Lower Bound:-219.39, Reconst:-204.74, KL:-14.64
# Epoch:99/100, Step:1100/2186, Lower Bound:-253.70, Reconst:-238.44, KL:-15.26
# Epoch:99/100, Step:1200/2186, Lower Bound:-244.37, Reconst:-229.49, KL:-14.88
# Epoch:99/100, Step:1300/2186, Lower Bound:-221.36, Reconst:-206.58, KL:-14.79
# Epoch:99/100, Step:1400/2186, Lower Bound:-264.98, Reconst:-249.40, KL:-15.58
# Epoch:99/100, Step:1500/2186, Lower Bound:-217.77, Reconst:-203.35, KL:-14.42
# Epoch:99/100, Step:1600/2186, Lower Bound:-234.80, Reconst:-220.27, KL:-14.54
# Epoch:99/100, Step:1700/2186, Lower Bound:-239.22, Reconst:-224.32, KL:-14.90
# Epoch:99/100, Step:1800/2186, Lower Bound:-250.12, Reconst:-234.62, KL:-15.50
# Epoch:99/100, Step:1900/2186, Lower Bound:-232.59, Reconst:-217.35, KL:-15.23
# Epoch:99/100, Step:2000/2186, Lower Bound:-242.01, Reconst:-226.82, KL:-15.19
# Epoch:99/100, Step:2100/2186, Lower Bound:-234.71, Reconst:-219.32, KL:-15.39
# Epoch:100/100, Step:100/2186, Lower Bound:-215.49, Reconst:-201.02, KL:-14.47
# Epoch:100/100, Step:200/2186, Lower Bound:-225.57, Reconst:-211.26, KL:-14.30
# Epoch:100/100, Step:300/2186, Lower Bound:-220.29, Reconst:-204.81, KL:-15.48
# Epoch:100/100, Step:400/2186, Lower Bound:-263.72, Reconst:-248.08, KL:-15.64
# Epoch:100/100, Step:500/2186, Lower Bound:-243.19, Reconst:-228.51, KL:-14.68
# Epoch:100/100, Step:600/2186, Lower Bound:-246.25, Reconst:-230.96, KL:-15.29
# Epoch:100/100, Step:700/2186, Lower Bound:-214.53, Reconst:-200.10, KL:-14.43
# Epoch:100/100, Step:800/2186, Lower Bound:-236.37, Reconst:-222.51, KL:-13.86
# Epoch:100/100, Step:900/2186, Lower Bound:-220.13, Reconst:-205.03, KL:-15.10
# Epoch:100/100, Step:1000/2186, Lower Bound:-245.49, Reconst:-230.24, KL:-15.26
# Epoch:100/100, Step:1100/2186, Lower Bound:-220.65, Reconst:-205.86, KL:-14.79
# Epoch:100/100, Step:1200/2186, Lower Bound:-242.98, Reconst:-228.00, KL:-14.98
# Epoch:100/100, Step:1300/2186, Lower Bound:-241.23, Reconst:-225.95, KL:-15.28
# Epoch:100/100, Step:1400/2186, Lower Bound:-239.07, Reconst:-224.45, KL:-14.62
# Epoch:100/100, Step:1500/2186, Lower Bound:-226.83, Reconst:-212.45, KL:-14.38
# Epoch:100/100, Step:1600/2186, Lower Bound:-227.77, Reconst:-213.15, KL:-14.62
# Epoch:100/100, Step:1700/2186, Lower Bound:-223.61, Reconst:-208.66, KL:-14.95
# Epoch:100/100, Step:1800/2186, Lower Bound:-260.05, Reconst:-244.56, KL:-15.49
# Epoch:100/100, Step:1900/2186, Lower Bound:-234.66, Reconst:-219.72, KL:-14.95
# Epoch:100/100, Step:2000/2186, Lower Bound:-239.65, Reconst:-224.87, KL:-14.78
# Epoch:100/100, Step:2100/2186, Lower Bound:-220.72, Reconst:-205.42, KL:-15.31

# %% [markdown]
# #####
